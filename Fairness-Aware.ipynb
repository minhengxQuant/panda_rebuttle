# %% [markdown]
# # Part I: Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.io import loadmat
from joblib import Parallel, delayed
import math
import random
import os
import time

def seed_everything(seed: int):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(0)
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Part II: Adversarial Debiasing Class

# %%
class Adversarial_Debiasing:
    def __init__(self, A, b, c, lamb, gamma, beta):
        self.A = A
        self.b = b
        self.c = c
        self.lamb = lamb
        self.gamma = gamma
        self.beta = beta
        self.m, self.dim = A.shape
        self.d = self.dim + 1
        self.n = A.shape[0]

    def grad(self, z):
        x = z[:self.dim]
        y = z[self.dim][0]
        p = 1 / (1 + np.exp(self.b * self.A @ x))
        q = 1 / (1 + np.exp(self.c * y * self.A @ x))
        gx = self.A.T @ (self.beta * y * q * self.c - p * self.b) / self.m + 2 * self.lamb * x
        gy = np.sum(self.beta * self.c * q * (self.A @ x)) / self.m - 2 * self.gamma * y
        g = np.zeros(self.d)
        g[:self.dim] = gx.flatten()
        g[-1] = gy
        return g.reshape(-1, 1)
    
    def Hxx(self, z):
        x = z[:self.dim]
        y = z[self.dim][0]
        p = 1 / (1 + np.exp(self.b * self.A @ x))
        q = 1 / (1 + np.exp(self.c * y * self.A @ x))
        
        return (self.A.T @ ((self.b**2 * (p - p**2) - self.beta * self.c**2 * y**2 * (q - q**2)) * self.A)) / self.m + 2 * self.lamb * np.eye(self.dim)
        
    
    def Hxy(self, z):
        x = z[:self.dim]
        y = z[self.dim][0]
        p = 1 / (1 + np.exp(self.b * self.A @ x))
        q = 1 / (1 + np.exp(self.c * y * self.A @ x))
        return self.beta * self.A.T @ (self.c * q) / self.m - ((self.beta * y * (q - q**2) * self.c**2) * self.A).T @ (self.A @ x) / self.m
        
    
    def Hyy(self, z):
        x = z[:self.dim]
        y = z[self.dim][0]
        p = 1 / (1 + np.exp(self.b * self.A @ x))
        q = 1 / (1 + np.exp(self.c * y * self.A @ x))
        return np.array([np.sum(-self.beta * self.c**2 * (self.A @ x)**2 * (q - q**2)) / self.m - 2 * self.gamma]).reshape(-1, 1)

# %%
class Adversarial_Debiasing_Sketch(Adversarial_Debiasing):
    def __init__(self, A, b, c, lamb, gamma, beta, method='uniform', pct=0.1):
        super().__init__(A, b, c, lamb, gamma, beta)
        self.method = method
        self.pct = pct
        self.sketch_size = int(self.pct * self.A.shape[0])
    
    def Hxx(self, z):
        x = z[:self.dim]
        y = z[self.dim][0]
        p = 1 / (1 + np.exp(self.b * self.A @ x))
        q = 1 / (1 + np.exp(self.c * y * self.A @ x))

        A0_aug = np.sqrt(self.b ** 2 * (p - p ** 2) - self.beta * self.c ** 2 * y ** 2 * (q - q ** 2)) * self.A

        if self.method == 'uniform':
            selected = np.random.choice(range(self.n), self.sketch_size, replace=False)
            return A0_aug[selected].T @ A0_aug[selected] / self.sketch_size + 2 * self.lamb * np.identity(self.dim)
        
        elif self.method == 'gaussian':
            S = np.random.normal(loc=0.0, scale=1/np.sqrt(self.sketch_size), size=(self.sketch_size, self.n))
            SA = S @ A0_aug
            return SA.T @ SA / self.sketch_size + 2 * self.lamb * np.identity(self.dim)

# %% [markdown]
# # Part III: PAN Framework

# %%
def PAN(params, A, b, c, lamb, gamma, beta, ratio=0.1, epochs=100, lr=1.0):
    gradients = []
    obj = Adversarial_Debiasing(A, b, c, lamb, gamma, beta)
    init_grad = np.linalg.norm(obj.grad(params), ord=2)
    cpu_time = [0.0]
    gradients.append(init_grad)
    print(f'epoch {0}, gradient norm: {init_grad}')
    sampled = np.random.choice(range(A.shape[0]), size=int(ratio * A.shape[0]), replace=False)
    A_sampled, b_sampled, c_sampled = A[sampled], b[sampled], c[sampled]
    local_obj = Adversarial_Debiasing(A_sampled, b_sampled, c_sampled, lamb, gamma, beta)
    
    for num_epoch in range(1, epochs+1):
        start_time = time.time()
        gz = obj.grad(params)
        gx, gy = gz[:-1].reshape(-1, 1), gz[-1].reshape(-1, 1)
        Hxy = obj.Hxy(params)
        Hyy = obj.Hyy(params)
        Hxx = local_obj.Hxx(params)
        Hxx_inv = np.linalg.inv(Hxx)
        Hyy_inv = np.linalg.inv(Hyy)
        
        G2 = Hyy - Hxy.T @ Hxx_inv @ Hxy
        G2_inv = np.linalg.inv(G2)
        G1_inv = Hxx_inv + (Hxx_inv @ Hxy) @ np.linalg.inv(G2) @ (Hxx_inv @ Hxy).T
        
        dx = G1_inv @ (gx - Hxy @ Hyy_inv @ gy)
        dy = G2_inv @ gy - Hyy_inv @ Hxy.T @ G1_inv @ gx
        d = np.vstack([dx, dy])
        
        params -= lr * d
        end_time = time.time()
        cpu_time.append(end_time - start_time)
        
        grad_norm = np.linalg.norm(obj.grad(params), ord=2)
        gradients.append(grad_norm)
        if num_epoch % 5 == 0:
            print(f'epoch {num_epoch}, gradient norm: {grad_norm}')
    
    return params, gradients, cpu_time

# %% [markdown]
# # Part IV: PANDA Algorithm

# %%
def PANDA(params, A, b, c, lamb, gamma, beta, n_workers=8, epochs=100, lr=1.0):
    gradients = []
    cpu_time = [0.0]
    
    N = A.shape[0]
    indices = np.arange(N)
    np.random.shuffle(indices)
    data_blocks = np.array_split(indices, n_workers)
    local_obj = [Adversarial_Debiasing(A[data_blocks[i]], b[data_blocks[i]], c[data_blocks[i]], lamb, gamma, beta) 
                 for i in range(n_workers)]
    init_grad = np.linalg.norm(np.mean([obj.grad(params) for obj in local_obj], axis=0), ord=2)
    gradients.append(init_grad)
    print(f'epoch {0}, gradient norm: {init_grad}')
    
    for num_epoch in range(1, epochs+1):
        time_count = 0.0
        
        g_xi, g_yi, H_xyi, H_yyi = [], [], [], []
        def parallel_mission1(worker_idx):
            obj = local_obj[worker_idx]
            gz = obj.grad(np.copy(params))
            gx, gy = gz[:-1].reshape(-1, 1), gz[-1].reshape(-1, 1)
            H_xy = obj.Hxy(np.copy(params)); H_yy = obj.Hyy(np.copy(params))
            g_xi.append(gx); g_yi.append(gy)
            H_xyi.append(H_xy); H_yyi.append(H_yy)
            return None
        
        ####### Start Parallel Mission 1
        local_start1 = time.time()
        Parallel(n_jobs=1, backend='threading')(delayed(parallel_mission1)(i) 
                                                 for i in range(n_workers))
        local_end1 = time.time()
        time_count += (local_end1 - local_start1) / n_workers
        
        server_start1 = time.time()
        g_x = np.mean(g_xi, axis=0).reshape(-1, 1)
        g_y = np.mean(g_yi, axis=0).reshape(-1, 1)
        H_xy = np.mean(H_xyi, axis=0).reshape(-1, 1)
        H_yy = np.mean(H_yyi, axis=0).reshape(-1, 1)
        server_end1 = time.time()
        time_count += (server_end1 - server_start1)
        
        pxi, pxyi = [], []
        def parallel_mission2(worker_idx):
            obj = local_obj[worker_idx]
            Hxx_inv = np.linalg.inv(obj.Hxx(np.copy(params)))
            px = Hxx_inv @ g_x; pxy = Hxx_inv @ H_xy
            pxi.append(px); pxyi.append(pxy)
            return None     
        
        local_start2 = time.time()
        Parallel(n_jobs=1, backend='threading')(delayed(parallel_mission2)(i) 
                                                 for i in range(n_workers))
        local_end2 = time.time()
        time_count += (local_end2 - local_start2) / n_workers
        
        server_start2 = time.time()
        p_xy = np.mean(pxyi, axis=0)
        p_x = np.mean(pxi, axis=0)

        C2 = H_yy - H_xy.T @ p_xy
        C2_inv = np.linalg.inv(C2)
        C1_inv_g_x = p_x + p_xy @ C2_inv @ H_xy.T @ p_x
        C1_inv_H_xy_H_yy_inv = p_xy @ np.linalg.inv(H_yy) + p_xy @ C2_inv @ H_xy.T @ p_xy @ np.linalg.inv(H_yy)
        
        d_x = C1_inv_g_x - C1_inv_H_xy_H_yy_inv @ g_y
        d_y = C2_inv @ g_y - np.linalg.inv(H_yy) @ H_xy.T @ C1_inv_g_x
        
        d = np.vstack([d_x, d_y])
        params = params - lr * d
        server_end2 = time.time()
        time_count += (server_end2 - server_start2)
        
        cpu_time.append(time_count)
        
        grad_norm = np.linalg.norm(np.mean([obj.grad(params) for obj in local_obj], axis=0), ord=2)
        gradients.append(grad_norm)
        if num_epoch % 5 == 0:
            print(f'epoch {num_epoch}, gradient norm: {grad_norm}')
        
    return params, gradients, cpu_time

# %% [markdown]
# # Part V: Extra Gradient & ProxSkip-VI Algorithms

# %%
def parallel_extra(params, A, b, c, lamb, gamma, beta, n_workers=8, epochs=100, lr=1.0):
    gradients = []
    cpu_time = [0.0]
    
    N = A.shape[0]
    indices = np.arange(N)
    np.random.shuffle(indices)
    data_blocks = np.array_split(indices, n_workers)
    local_obj = [Adversarial_Debiasing(A[data_blocks[i]], b[data_blocks[i]], c[data_blocks[i]], lamb, gamma, beta) 
                 for i in range(n_workers)]
    init_grad = np.linalg.norm(np.mean([obj.grad(params) for obj in local_obj], axis=0), ord=2)
    gradients.append(init_grad)
    print(f'epoch {0}, gradient norm: {init_grad}')
    
    for num_epoch in range(1, epochs+1):
        time_count = 0.0
        
        g_xi, g_yi = [], []
        def parallel_mission1(worker_idx):
            obj = local_obj[worker_idx]
            gz = obj.grad(params)
            gx, gy = gz[:-1].reshape(-1, 1), gz[-1].reshape(-1, 1)
            g_xi.append(gx)
            g_yi.append(gy)
            return None
        
        local_start1 = time.time()
        Parallel(n_jobs=1, backend='threading')(delayed(parallel_mission1)(i) 
                                              for i in range(n_workers))
        local_end1 = time.time()
        time_count += (local_end1 - local_start1) / n_workers
        
        server_start1 = time.time()
        g_x = np.mean(g_xi, axis=0)
        g_y = np.mean(g_yi, axis=0)
        server_end1 = time.time()
        time_count += (server_end1 - server_start1)
        
        server_start2 = time.time()
        params_temp = np.copy(params)
        params_temp[:-1] -= lr * g_x
        params_temp[-1] += lr * g_y.flatten()
        server_end2 = time.time()
        time_count += (server_end2 - server_start2)
        
        g_xi, g_yi = [], []
        def parallel_mission2(worker_idx):
            obj = local_obj[worker_idx]
            gz = obj.grad(params_temp)
            gx, gy = gz[:-1].reshape(-1, 1), gz[-1].reshape(-1, 1)
            g_xi.append(gx)
            g_yi.append(gy)
            return None
        
        local_start2 = time.time()
        Parallel(n_jobs=1, backend='threading')(delayed(parallel_mission2)(i) 
                                              for i in range(n_workers))
        local_end2 = time.time()
        time_count += (local_end2 - local_start2) / n_workers
        
        server_start3 = time.time()
        g_x = np.mean(g_xi, axis=0)
        g_y = np.mean(g_yi, axis=0)
        params[:-1] -= lr * g_x
        params[-1] += lr * g_y.flatten()
        server_end3 = time.time()
        time_count += (server_end3 - server_start3)
        
        cpu_time.append(time_count)
        grad_norm = np.linalg.norm(np.mean([obj.grad(params) for obj in local_obj], axis=0), ord=2)
        gradients.append(grad_norm)
        if num_epoch % 20 == 0:
            print(f'epoch {num_epoch}, gradient norm: {grad_norm}')
        
    return params, gradients, cpu_time

# %%
def proxskip(params, control, A, b, c, lamb, gamma, beta, n_workers=8, epochs=100, lr=1.0, prob=0.4):
    gradients = []
    cpu_time = [0.0]
    N = A.shape[0]
    indices = np.arange(N)
    np.random.shuffle(indices)
    data_blocks = np.array_split(indices, n_workers)
    local_obj = [Adversarial_Debiasing(A[data_blocks[i]], b[data_blocks[i]], c[data_blocks[i]], lamb, gamma, beta) 
                 for i in range(n_workers)]
    init_grad = np.linalg.norm(np.mean([obj.grad(params) for obj in local_obj], axis=0), ord=2)
    gradients.append(init_grad)
    print(f'epoch {0}, gradient norm: {init_grad}')
    
    local_params = np.repeat(params, n_workers, axis=1)
    local_params_hat = np.copy(local_params)
    local_params_prime = np.copy(local_params)
    local_controls = np.repeat(control, n_workers, axis=1)
    updates = np.random.binomial(1, prob, size=epochs)
    lr2 = lr / prob
    lr3 = 1 / lr2

    for num_epoch in range(1, epochs+1):
        update = updates[num_epoch-1]
        if num_epoch == 1 or updates[num_epoch-2] == 1:
            time_count = 0.0
            
        def parallel_mission1(worker_idx):
            obj = local_obj[worker_idx]
            worker_params = local_params[:, [worker_idx]]
            gz = obj.grad(worker_params)
            gx, gy = gz[:-1].reshape(-1, 1), gz[-1].reshape(-1, 1)
            local_params_hat[:-1, [worker_idx]] = local_params[:-1, [worker_idx]] - lr * (gx - local_controls[:-1, [worker_idx]])
            local_params_hat[-1, [worker_idx]] = local_params[-1, [worker_idx]] + lr * (gy.flatten() - local_controls[-1, [worker_idx]])

            if update == 1:
                local_params_prime[:-1, [worker_idx]] = local_params_hat[:-1, [worker_idx]] - lr2 * local_controls[:-1, [worker_idx]]
                local_params_prime[-1, [worker_idx]] = local_params_hat[-1, [worker_idx]] + lr2 * local_controls[-1, [worker_idx]]

            else:
                local_params[:, [worker_idx]] = local_params_hat[:, [worker_idx]]

            return None
    
        local_start1 = time.time()
        Parallel(n_jobs=1, backend='threading')(delayed(parallel_mission1)(i) 
                                              for i in range(n_workers))
        local_end1 = time.time()
        time_count += (local_end1 - local_start1) / n_workers
        
        if update == 1:
            server_start1 = time.time()
            avg_params = np.mean(local_params_prime, axis=1, keepdims=True)
            local_params = np.repeat(avg_params, n_workers, axis=1)
            server_end1 = time.time()
            time_count += (server_end1 - server_end1)
            cpu_time.append(time_count)
            
            grad_norm = np.linalg.norm(np.mean([obj.grad(avg_params) for obj in local_obj], axis=0), ord=2)
            gradients.append(grad_norm)
            print(f'epoch {num_epoch}, gradient norm: {grad_norm}')
        
        def parallel_mission2(worker_idx):
            local_controls[:-1, [worker_idx]] += lr3 * (local_params[:-1, [worker_idx]] - local_params_hat[:-1, [worker_idx]])
            local_controls[-1, [worker_idx]] += lr3 * (-local_params[-1, [worker_idx]] + local_params_hat[-1, [worker_idx]])
            return None
        
        local_start2 = time.time()
        Parallel(n_jobs=1, backend='threading')(delayed(parallel_mission2)(i) 
                                              for i in range(n_workers))
        local_end2 = time.time()
        time_count += (local_end2 - local_start2) / n_workers
        
    return avg_params, gradients, cpu_time

# %% [markdown]
# # Part VI: GIANT-PANDA Algorithm

# %%
def GIANT_PANDA(params, A, b, c, lamb, gamma, beta, n_workers=8, epochs=100, lr=1.0, method='uniform', pct=0.1):
    gradients = []
    cpu_time = [0.0]
    N = A.shape[0]
    indices = np.arange(N)
    np.random.shuffle(indices)
    data_blocks = np.array_split(indices, n_workers)
    local_obj = [Adversarial_Debiasing(A[data_blocks[i]], 
                                       b[data_blocks[i]], 
                                       c[data_blocks[i]], 
                                       lamb, gamma, beta) 
                 for i in range(n_workers)]
    init_grad = np.linalg.norm(np.mean([obj.grad(params) for obj in local_obj], axis=0), ord=2)
    gradients.append(init_grad)
    print(f'epoch {0}, gradient norm: {init_grad}')
    
    for num_epoch in range(1, epochs+1):
        time_count = 0.0
        g_xi, g_yi, H_xyi, H_yyi = [], [], [], []
        sub_objs = [Adversarial_Debiasing_Sketch(x.A, x.b, x.c, lamb, gamma, beta, method, pct) for x in local_obj]
        
        def parallel_mission1(worker_idx):
            obj = sub_objs[worker_idx]
            gz = obj.grad(np.copy(params))
            gx, gy = gz[:-1].reshape(-1, 1), gz[-1].reshape(-1, 1)
            H_xy = obj.Hxy(np.copy(params)); H_yy = obj.Hyy(np.copy(params))
            g_xi.append(gx); g_yi.append(gy)
            H_xyi.append(H_xy); H_yyi.append(H_yy)
            return None
        
        local_start1 = time.time()
        Parallel(n_jobs=1, backend='threading')(delayed(parallel_mission1)(i) 
                                                 for i in range(n_workers))
        local_end1 = time.time()
        time_count += (local_end1 - local_start1) / n_workers
        
        server_start1 = time.time()
        g_x = np.mean(g_xi, axis=0).reshape(-1, 1)
        g_y = np.mean(g_yi, axis=0).reshape(-1, 1)
        H_xy = np.mean(H_xyi, axis=0).reshape(-1, 1)
        H_yy = np.mean(H_yyi, axis=0).reshape(-1, 1)
        server_end1 = time.time()
        time_count += (server_end1 - server_start1)
        
        pxi, pxyi = [], []
        def parallel_mission2(worker_idx):
            obj = sub_objs[worker_idx]
            Hxx_inv = np.linalg.inv(obj.Hxx(np.copy(params)))
            px = Hxx_inv @ g_x; pxy = Hxx_inv @ H_xy
            pxi.append(px); pxyi.append(pxy)
            return None     
        
        local_start2 = time.time()
        Parallel(n_jobs=1, backend='threading')(delayed(parallel_mission2)(i) 
                                                 for i in range(n_workers))
        local_end2 = time.time()
        time_count += (local_end2 - local_start2) / n_workers
        
        server_start2 = time.time()
        p_xy = np.mean(pxyi, axis=0)
        p_x = np.mean(pxi, axis=0)
        
        C2 = H_yy - H_xy.T @ p_xy
        C2_inv = np.linalg.inv(C2)
        C1_inv_g_x = p_x + p_xy @ C2_inv @ H_xy.T @ p_x
        C1_inv_H_xy_H_yy_inv = p_xy @ np.linalg.inv(H_yy) + p_xy @ C2_inv @ H_xy.T @ p_xy @ np.linalg.inv(H_yy)
        
        d_x = C1_inv_g_x - C1_inv_H_xy_H_yy_inv @ g_y
        d_y = C2_inv @ g_y - np.linalg.inv(H_yy) @ H_xy.T @ C1_inv_g_x
        
        d = np.vstack([d_x, d_y])
        params = params - lr * d
        server_end2 = time.time()
        time_count += (server_end2 - server_start2)
        
        cpu_time.append(time_count)
        grad_norm = np.linalg.norm(np.mean([obj.grad(params) for obj in local_obj], axis=0), ord=2)
        gradients.append(grad_norm)
        if num_epoch % 5 == 0:
            print(f'epoch {num_epoch}, gradient norm: {grad_norm}')
        
    return params, gradients, cpu_time

# %% [markdown]
# # Part VII: a9a Dataset

# %%
m = loadmat('a9a.mat')
A0 = np.array(m['A']).astype("float")
b = np.array(m['b']).astype("float")
c = A0[:,71]
A = np.hstack((A0[:,:71],A0[:,72:]))
c[np.where(c == 0)[0]] = -1
c = c.reshape(A0.shape[0],1)

# %%
A.shape
# Out:
# (32561, 122)

# %% [markdown]
# ## Part VII-I: PAN Solution

# %%
# PAN(5%)
params = np.zeros(123).reshape(-1, 1)
params_pan_5, gradients_pan_5, time_pan_5 = PAN(params, A, b, c, 0.0001, 0.0001, 0.5, ratio=0.05, epochs=500, lr=1.0)
# Out:
# epoch 0, gradient norm: 0.6612688562040967
# epoch 5, gradient norm: 0.0038578195215161993
# epoch 10, gradient norm: 0.004460884435641053
# epoch 15, gradient norm: 0.00569981672822834
# epoch 20, gradient norm: 0.006573575837128978
# epoch 25, gradient norm: 0.00787040458533466
# epoch 30, gradient norm: 0.00613820195356965
# epoch 35, gradient norm: 0.0052462465460702025
# epoch 40, gradient norm: 0.0067910005132097604
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 # PAN Algorithm, with 5% samples per iteration
#       2 params = np.zeros(123).reshape(-1, 1)
# ----> 3 params_pan_5, gradients_pan_5, time_pan_5 = PAN(params, A, b, c, 0.0001, 0.0001, 0.5, ratio=0.05, epochs=500, lr=1.0)
#
# Cell In[3], line 16, in PAN(params, A, b, c, lamb, gamma, beta, ratio, epochs, lr)
#      14 start_time = time.time()
#      15 # Compute Update Directions (Block Inverse Formula)
# ---> 16 gz = obj.grad(params)
#      17 gx, gy = gz[:-1].reshape(-1, 1), gz[-1].reshape(-1, 1)
#      18 Hxy = obj.Hxy(params)
#
# Cell In[2], line 27, in Adversarial_Debiasing.grad(self, z)
#      25 x = z[:self.dim]
#      26 y = z[self.dim][0]
# ---> 27 p = 1 / (1 + np.exp(self.b * self.A @ x))               # shape (m, 1)
#      28 q = 1 / (1 + np.exp(self.c * y * self.A @ x))     # shape (m, 1)
#      29 gx = self.A.T @ (self.beta * y * q * self.c - p * self.b) / self.m + 2 * self.lamb * x
#
# KeyboardInterrupt:

# %%
# PAN(10%)
params = np.zeros(123).reshape(-1, 1)
params_pan_10, gradients_pan_10, time_pan_10 = PAN(params, A, b, c, 0.0001, 0.0001, 0.5, ratio=0.1, epochs=100, lr=1.0)
# Out:
# epoch 0, gradient norm: 0.6612688562040967
# epoch 5, gradient norm: 0.00030131253099683643
# epoch 10, gradient norm: 2.1605141205726847e-07
# epoch 15, gradient norm: 1.5772656516389222e-10
# epoch 20, gradient norm: 2.1596908023432706e-13
# epoch 25, gradient norm: 4.991624131890611e-16
# epoch 30, gradient norm: 3.900739362107925e-17
# epoch 35, gradient norm: 2.6574713700545633e-17
# epoch 40, gradient norm: 4.390351855649948e-17
# epoch 45, gradient norm: 1.600670497107787e-17
# epoch 50, gradient norm: 1.6963002420597952e-17
# epoch 55, gradient norm: 4.7462332622374665e-17
# epoch 60, gradient norm: 2.881896137816099e-17
# epoch 65, gradient norm: 5.209762794118781e-17
# epoch 70, gradient norm: 1.0286465342079387e-17
# epoch 75, gradient norm: 5.0056633470325984e-17
# epoch 80, gradient norm: 2.481607803826819e-17
# epoch 85, gradient norm: 1.6836986029809348e-17
# epoch 90, gradient norm: 5.895530175165075e-17
# epoch 95, gradient norm: 2.829266603242507e-17
# epoch 100, gradient norm: 1.9630255551569386e-17

# %%
# PAN(20%)
params = np.zeros(123).reshape(-1, 1)
params_pan_20, gradients_pan_20, time_pan_20 = PAN(params, A, b, c, 0.0001, 0.0001, 0.5, ratio=0.2, epochs=100, lr=1.0)
# Out:
# epoch 0, gradient norm: 0.6612688562040967
# epoch 5, gradient norm: 0.00012436806666263895
# epoch 10, gradient norm: 1.668092669449058e-08
# epoch 15, gradient norm: 4.1657296475093354e-12
# epoch 20, gradient norm: 6.212637282172057e-16
# epoch 25, gradient norm: 2.443334448538217e-17
# epoch 30, gradient norm: 1.3178690460058379e-17
# epoch 35, gradient norm: 4.3820704132122786e-17
# epoch 40, gradient norm: 4.8037586314873385e-17
# epoch 45, gradient norm: 1.9795860934922297e-17
# epoch 50, gradient norm: 7.908902900274948e-18
# epoch 55, gradient norm: 1.6671195984889157e-17
# epoch 60, gradient norm: 3.265834250476961e-17
# epoch 65, gradient norm: 4.632224849146657e-17
# epoch 70, gradient norm: 1.4491100227772756e-17
# epoch 75, gradient norm: 5.162673933201004e-17
# epoch 80, gradient norm: 4.293717207376464e-17
# epoch 85, gradient norm: 5.622530045551061e-17
# epoch 90, gradient norm: 4.457201512469702e-17
# epoch 95, gradient norm: 8.28811378752027e-18
# epoch 100, gradient norm: 2.6817927947173176e-17

# %% [markdown]
# ## Part VII-II: PANDA Solution

# %%
# PANDA(4)
params = np.zeros(123).reshape(-1, 1)
params_nt_4, gradients_nt_4, time_nt_4 = parallel_nt(params, A, b, c, 0.0001, 0.0001, 0.5, n_workers=4, epochs=100, lr=1.0)
# Out:
# epoch 0, gradient norm: 0.6612686076732777
# epoch 5, gradient norm: 0.00021057779872244665
# epoch 10, gradient norm: 1.1729996942228272e-12
# epoch 15, gradient norm: 2.5043635483832864e-17
# epoch 20, gradient norm: 2.105692745693514e-17
# epoch 25, gradient norm: 4.780405289641596e-17
# epoch 30, gradient norm: 2.2136919326595576e-17
# epoch 35, gradient norm: 1.3613653592846576e-17
# epoch 40, gradient norm: 3.001989424046837e-17
# epoch 45, gradient norm: 3.7973999840935435e-17
# epoch 50, gradient norm: 1.3749898273782841e-17
# epoch 55, gradient norm: 2.121069172019686e-17
# epoch 60, gradient norm: 2.809000906481296e-17
# epoch 65, gradient norm: 3.4271964460016653e-17
# epoch 70, gradient norm: 3.058439519101444e-17
# epoch 75, gradient norm: 3.491350418206587e-17
# epoch 80, gradient norm: 3.917147386847454e-17
# epoch 85, gradient norm: 8.425494302060812e-17
# epoch 90, gradient norm: 3.8897559419236617e-17
# epoch 95, gradient norm: 2.91999944310401e-17
# epoch 100, gradient norm: 6.076714309408818e-18

# %%
# PANDA(8)
params = np.zeros(123).reshape(-1, 1)
params_nt_8, gradients_nt_8, time_nt_8 = parallel_nt(params, A, b, c, 0.0001, 0.0001, 0.5, n_workers=8, epochs=100, lr=1.0)
# Out:
# epoch 0, gradient norm: 0.6612689971582043
# epoch 5, gradient norm: 0.00018676300083661284
# epoch 10, gradient norm: 1.7100279312953336e-11
# epoch 15, gradient norm: 5.818890614954898e-16
# epoch 20, gradient norm: 2.6154850464658624e-17
# epoch 25, gradient norm: 2.6615935141568778e-17
# epoch 30, gradient norm: 1.2287077276572544e-17
# epoch 35, gradient norm: 1.5027884407615935e-17
# epoch 40, gradient norm: 3.8276397985369775e-17
# epoch 45, gradient norm: 1.8646575449458593e-17
# epoch 50, gradient norm: 7.627406992629827e-17
# epoch 55, gradient norm: 6.271705124460136e-17
# epoch 60, gradient norm: 1.1575375487948042e-17
# epoch 65, gradient norm: 1.6618179517286713e-17
# epoch 70, gradient norm: 2.533600819017849e-17
# epoch 75, gradient norm: 7.688505247258e-17
# epoch 80, gradient norm: 1.730099036441236e-17
# epoch 85, gradient norm: 5.760975642944773e-17
# epoch 90, gradient norm: 3.13606557915681e-17
# epoch 95, gradient norm: 1.2596236563388429e-17
# epoch 100, gradient norm: 2.568593445890809e-17

# %%
# PANDA(16)
params = np.zeros(123).reshape(-1, 1)
params_nt_16, gradients_nt_16, time_nt_16 = parallel_nt(params, A, b, c, 0.0001, 0.0001, 0.5, n_workers=16, epochs=100, lr=1.0)
# Out:
# epoch 0, gradient norm: 0.6612695932533036
# epoch 5, gradient norm: 0.00014505849461540624
# epoch 10, gradient norm: 5.1096338932256496e-09
# epoch 15, gradient norm: 6.369118145364914e-12
# epoch 20, gradient norm: 9.491613828362548e-15
# epoch 25, gradient norm: 3.590104018618651e-17
# epoch 30, gradient norm: 8.704187481892118e-17
# epoch 35, gradient norm: 3.541584418010261e-17
# epoch 40, gradient norm: 2.0357451851308164e-17
# epoch 45, gradient norm: 4.3308081839623054e-17
# epoch 50, gradient norm: 5.58181734343633e-17
# epoch 55, gradient norm: 2.948935905068323e-17
# epoch 60, gradient norm: 1.2892043691421485e-17
# epoch 65, gradient norm: 2.672642894477224e-17
# epoch 70, gradient norm: 7.174457866539177e-18
# epoch 75, gradient norm: 5.85109139447481e-18
# epoch 80, gradient norm: 2.1208274594064347e-17
# epoch 85, gradient norm: 3.628799530153978e-17
# epoch 90, gradient norm: 1.3450754038021956e-17
# epoch 95, gradient norm: 4.579826409259996e-17
# epoch 100, gradient norm: 1.798987686999606e-17

# %%
# PANDA(32)
params = np.zeros(123).reshape(-1, 1)
params_nt_32, gradients_nt_32, time_nt_32 = parallel_nt(params, A, b, c, 0.0001, 0.0001, 0.5, n_workers=32, epochs=100, lr=1.0)
# Out:
# epoch 0, gradient norm: 0.6612651821458368
# epoch 5, gradient norm: 5.6447797235583e-05
# epoch 10, gradient norm: 1.3363274599890471e-06
# epoch 15, gradient norm: 3.875979525149503e-08
# epoch 20, gradient norm: 1.1286425038001568e-09
# epoch 25, gradient norm: 3.2958512739129765e-11
# epoch 30, gradient norm: 9.638008450794912e-13
# epoch 35, gradient norm: 2.8242287212383336e-14
# epoch 40, gradient norm: 8.041724397137658e-16
# epoch 45, gradient norm: 4.5455410162172173e-17
# epoch 50, gradient norm: 7.317604487066302e-17
# epoch 55, gradient norm: 3.3426319347669457e-17
# epoch 60, gradient norm: 1.1569183612725705e-17
# epoch 65, gradient norm: 7.739537409843066e-18
# epoch 70, gradient norm: 2.6642424341172376e-17
# epoch 75, gradient norm: 2.6419977650792923e-17
# epoch 80, gradient norm: 1.4463697146098785e-17
# epoch 85, gradient norm: 1.1554642726343487e-17
# epoch 90, gradient norm: 8.361184490880083e-17
# epoch 95, gradient norm: 8.64982897390796e-18
# epoch 100, gradient norm: 9.242451632283113e-18

# %% [markdown]
# ## Part VII-III: ProxSkip-VI-FL Solution

# %%
# ProxSkip (8)
params = np.zeros(123).reshape(-1, 1)
control = np.zeros(123).reshape(-1, 1)
params_ps_8, gradients_ps_8, time_ps_8 = proxskip(params, control, A, b, c, 0.0001, 0.0001, 0.5, n_workers=8, epochs=8000, lr=1.0, prob=0.4)

# %% [markdown]
# ## Part VII-IV: EG Solution

# %%
# EG(8)
params = np.zeros(123).reshape(-1, 1)
params_extragrad_8, gradients_extragrad_8, time_extragrad_8 = parallel_extra(params, A, b, c, 0.0001, 0.0001, 0.5, n_workers=8, epochs=12000, lr=0.7)
# Out:
# epoch 0, gradient norm: 0.6612699149892407
# epoch 20, gradient norm: 0.06043776576116855
# epoch 40, gradient norm: 0.030868327703461873
# epoch 60, gradient norm: 0.022301360274171542
# epoch 80, gradient norm: 0.017528030821039032
# epoch 100, gradient norm: 0.014387427516963655
# epoch 120, gradient norm: 0.012154497145571236
# epoch 140, gradient norm: 0.01049110614354109
# epoch 160, gradient norm: 0.009209073254236281
# epoch 180, gradient norm: 0.008193627213011135
# epoch 200, gradient norm: 0.007370863008992806
# epoch 220, gradient norm: 0.006691304808027721
# epoch 240, gradient norm: 0.006120767503650975
# epoch 260, gradient norm: 0.005634978728421488
# epoch 280, gradient norm: 0.00521628616066542
# epoch 300, gradient norm: 0.004851576428594963
# epoch 320, gradient norm: 0.004530922767401527
# epoch 340, gradient norm: 0.004246683875301692
# epoch 360, gradient norm: 0.0039928894326311205
# epoch 380, gradient norm: 0.003764812126328067
# epoch 400, gradient norm: 0.0035586637288780375
# epoch 420, gradient norm: 0.0033713754128244337
# epoch 440, gradient norm: 0.0032004363735759715
# epoch 460, gradient norm: 0.003043773540478117
# epoch 480, gradient norm: 0.0028996607230961703
# epoch 500, gradient norm: 0.0027666491667412813
# epoch 520, gradient norm: 0.0026435138973559817
# epoch 540, gradient norm: 0.002529211859565199
# epoch 560, gradient norm: 0.0024228489653518965
# epoch 580, gradient norm: 0.002323653946452777
# epoch 600, gradient norm: 0.002230957451627013
# epoch 620, gradient norm: 0.002144175222461705
# epoch 640, gradient norm: 0.00206279446604365
# epoch 660, gradient norm: 0.001986362751705154
# epoch 680, gradient norm: 0.0019144789139878089
# epoch 700, gradient norm: 0.0018467855600507897
# epoch 720, gradient norm: 0.0017829628675322155
# epoch 740, gradient norm: 0.0017227234258246384
# epoch 760, gradient norm: 0.001665807925196766
# epoch 780, gradient norm: 0.0016119815380537864
# epoch 800, gradient norm: 0.001561030867706787
# epoch 820, gradient norm: 0.001512761364404944
# epoch 840, gradient norm: 0.0014669951276262082
# epoch 860, gradient norm: 0.00142356902888905
# epoch 880, gradient norm: 0.001382333101521772
# epoch 900, gradient norm: 0.00134314915357911
# epoch 920, gradient norm: 0.0013058895679437892
# epoch 940, gradient norm: 0.0012704362599917386
# epoch 960, gradient norm: 0.0012366797683429022
# epoch 980, gradient norm: 0.001204518458406411
# epoch 1000, gradient norm: 0.001173857821849135
# epoch 1020, gradient norm: 0.001144609857919525
# epoch 1040, gradient norm: 0.0011166925248630544
# epoch 1060, gradient norm: 0.001090029251565461
# epoch 1080, gradient norm: 0.0010645485011309495
# epoch 1100, gradient norm: 0.0010401833794049667
# epoch 1120, gradient norm: 0.0010168712825335807
# epoch 1140, gradient norm: 0.0009945535785534881
# epoch 1160, gradient norm: 0.000973175318759784
# epoch 1180, gradient norm: 0.0009526849752290585
# epoch 1200, gradient norm: 0.0009330342014039971
# epoch 1220, gradient norm: 0.0009141776130899535
# epoch 1240, gradient norm: 0.0008960725875880508
# epoch 1260, gradient norm: 0.0008786790790048252
# epoch 1280, gradient norm: 0.0008619594480451533
# epoch 1300, gradient norm: 0.0008458783048208212
# epoch 1320, gradient norm: 0.0008304023633986126
# epoch 1340, gradient norm: 0.0008155003069743137
# epoch 1360, gradient norm: 0.0008011426626975179
# epoch 1380, gradient norm: 0.0007873016852900828
# epoch 1400, gradient norm: 0.0007739512487019794
# epoch 1420, gradient norm: 0.0007610667451346122
# epoch 1440, gradient norm: 0.0007486249908358229
# epoch 1460, gradient norm: 0.0007366041381345782
# epoch 1480, gradient norm: 0.0007249835932383841
# epoch 1500, gradient norm: 0.0007137439393641095
# epoch 1520, gradient norm: 0.0007028668648142632
# epoch 1540, gradient norm: 0.0006923350956468318
# epoch 1560, gradient norm: 0.0006821323326182991
# epoch 1580, gradient norm: 0.000672243192107167
# epoch 1600, gradient norm: 0.0006626531507497227
# epoch 1620, gradient norm: 0.0006533484935414234
# epoch 1640, gradient norm: 0.0006443162651765263
# epoch 1660, gradient norm: 0.0006355442244157853
# epoch 1680, gradient norm: 0.0006270208012875164
# epoch 1700, gradient norm: 0.0006187350569412256
# epoch 1720, gradient norm: 0.0006106766459856964
# epoch 1740, gradient norm: 0.0006028357811548449
# epoch 1760, gradient norm: 0.0005952032001552256
# epoch 1780, gradient norm: 0.0005877701345586602
# epoch 1800, gradient norm: 0.0005805282806123539
# epoch 1820, gradient norm: 0.000573469771847029
# epoch 1840, gradient norm: 0.0005665871533712223
# epoch 1860, gradient norm: 0.0005598733577468944
# epoch 1880, gradient norm: 0.00055332168234809
# epoch 1900, gradient norm: 0.0005469257681104734
# epoch 1920, gradient norm: 0.0005406795795852876
# epoch 1940, gradient norm: 0.0005345773862166219
# epoch 1960, gradient norm: 0.0005286137447658729
# epoch 1980, gradient norm: 0.0005227834828119731
# epoch 2000, gradient norm: 0.0005170816832603753
# epoch 2020, gradient norm: 0.0005115036697978844
# epoch 2040, gradient norm: 0.0005060449932343428
# epoch 2060, gradient norm: 0.0005007014186757936
# epoch 2080, gradient norm: 0.000495468913477185
# epoch 2100, gradient norm: 0.0004903436359259048
# epoch 2120, gradient norm: 0.0004853219246104424
# epoch 2140, gradient norm: 0.0004804002884313426
# epoch 2160, gradient norm: 0.0004755753972142772
# epoch 2180, gradient norm: 0.00047084407288756365
# epoch 2200, gradient norm: 0.0004662032811888467
# epoch 2220, gradient norm: 0.00046165012386784954
# epoch 2240, gradient norm: 0.0004571818313541904
# epoch 2260, gradient norm: 0.00045279575586123
# epoch 2280, gradient norm: 0.0004484893648987173
# epoch 2300, gradient norm: 0.0004442602351687619
# epoch 2320, gradient norm: 0.00044010604682124285
# epoch 2340, gradient norm: 0.000436024578046291
# epoch 2360, gradient norm: 0.0004320136999829049
# epoch 2380, gradient norm: 0.0004280713719240924
# epoch 2400, gradient norm: 0.0004241956368001572
# epoch 2420, gradient norm: 0.00042038461692295114
# epoch 2440, gradient norm: 0.00041663650997497237
# epoch 2460, gradient norm: 0.0004129495852282524
# epoch 2480, gradient norm: 0.0004093221799788877
# epoch 2500, gradient norm: 0.00040575269618402574
# epoch 2520, gradient norm: 0.00040223959728890625
# epoch 2540, gradient norm: 0.00039878140523237334
# epoch 2560, gradient norm: 0.0003953766976200104
# epoch 2580, gradient norm: 0.0003920241050547241
# epoch 2600, gradient norm: 0.0003887223086152612
# epoch 2620, gradient norm: 0.00038547003747374466
# epoch 2640, gradient norm: 0.0003822660666438704
# epoch 2660, gradient norm: 0.00037910921485194394
# epoch 2680, gradient norm: 0.00037599834252342363
# epoch 2700, gradient norm: 0.00037293234987810677
# epoch 2720, gradient norm: 0.00036991017512750965
# epoch 2740, gradient norm: 0.00036693079276842183
# epoch 2760, gradient norm: 0.00036399321196696667
# epoch 2780, gradient norm: 0.0003610964750278721
# epoch 2800, gradient norm: 0.0003582396559439791
# epoch 2820, gradient norm: 0.00035542185902132057
# epoch 2840, gradient norm: 0.0003526422175754022
# epoch 2860, gradient norm: 0.0003498998926945759
# epoch 2880, gradient norm: 0.0003471940720666595
# epoch 2900, gradient norm: 0.00034452396886518877
# epoch 2920, gradient norm: 0.00034188882069190397
# epoch 2940, gradient norm: 0.00033928788857229427
# epoch 2960, gradient norm: 0.00033672045600120185
# epoch 2980, gradient norm: 0.00033418582803568025
# epoch 3000, gradient norm: 0.0003316833304324661
# epoch 3020, gradient norm: 0.0003292123088275842
# epoch 3040, gradient norm: 0.0003267721279557561
# epoch 3060, gradient norm: 0.0003243621709074167
# epoch 3080, gradient norm: 0.00032198183842128573
# epoch 3100, gradient norm: 0.0003196305482105446
# epoch 3120, gradient norm: 0.0003173077343208098
# epoch 3140, gradient norm: 0.000315012846518173
# epoch 3160, gradient norm: 0.0003127453497056994
# epoch 3180, gradient norm: 0.0003105047233668689
# epoch 3200, gradient norm: 0.0003082904610345173
# epoch 3220, gradient norm: 0.00030610206978393963
# epoch 3240, gradient norm: 0.0003039390697488782
# epoch 3260, gradient norm: 0.0003018009936592009
# epoch 3280, gradient norm: 0.0002996873863991446
# epoch 3300, gradient norm: 0.0002975978045850494
# epoch 3320, gradient norm: 0.0002955318161615959
# epoch 3340, gradient norm: 0.0002934890000155849
# epoch 3360, gradient norm: 0.0002914689456063725
# epoch 3380, gradient norm: 0.0002894712526121209
# epoch 3400, gradient norm: 0.00028749553059106053
# epoch 3420, gradient norm: 0.0002855413986570231
# epoch 3440, gradient norm: 0.00028360848516852626
# epoch 3460, gradient norm: 0.00028169642743074743
# epoch 3480, gradient norm: 0.00027980487140974496
# epoch 3500, gradient norm: 0.0002779334714583347
# epoch 3520, gradient norm: 0.0002760818900530569
# epoch 3540, gradient norm: 0.00027424979754168727
# epoch 3560, gradient norm: 0.0002724368719008012
# epoch 3580, gradient norm: 0.0002706427985028981
# epoch 3600, gradient norm: 0.0002688672698926408
# epoch 3620, gradient norm: 0.00026710998557177585
# epoch 3640, gradient norm: 0.00026537065179233453
# epoch 3660, gradient norm: 0.0002636489813577207
# epoch 3680, gradient norm: 0.00026194469343132626
# epoch 3700, gradient norm: 0.00026025751335232946
# epoch 3720, gradient norm: 0.00025858717245834454
# epoch 3740, gradient norm: 0.0002569334079146123
# epoch 3760, gradient norm: 0.00025529596254944244
# epoch 3780, gradient norm: 0.0002536745846956196
# epoch 3800, gradient norm: 0.0002520690280375144
# epoch 3820, gradient norm: 0.00025047905146364445
# epoch 3840, gradient norm: 0.00024890441892444915
# epoch 3860, gradient norm: 0.00024734489929504743
# epoch 3880, gradient norm: 0.00024580026624276564
# epoch 3900, gradient norm: 0.00024427029809922986
# epoch 3920, gradient norm: 0.00024275477773682858
# epoch 3940, gradient norm: 0.00024125349244935975
# epoch 3960, gradient norm: 0.00023976623383668592
# epoch 3980, gradient norm: 0.00023829279769323232
# epoch 4000, gradient norm: 0.000236832983900168
# epoch 4020, gradient norm: 0.00023538659632111136
# epoch 4040, gradient norm: 0.00023395344270123292
# epoch 4060, gradient norm: 0.00023253333456959687
# epoch 4080, gradient norm: 0.0002311260871446282
# epoch 4100, gradient norm: 0.00022973151924256927
# epoch 4120, gradient norm: 0.00022834945318881293
# epoch 4140, gradient norm: 0.00022697971473200064
# epoch 4160, gradient norm: 0.00022562213296076908
# epoch 4180, gradient norm: 0.00022427654022305163
# epoch 4200, gradient norm: 0.00022294277204783252
# epoch 4220, gradient norm: 0.00022162066706926057
# epoch 4240, gradient norm: 0.00022031006695303178
# epoch 4260, gradient norm: 0.0002190108163249573
# epoch 4280, gradient norm: 0.00021772276270163742
# epoch 4300, gradient norm: 0.00021644575642315573
# epoch 4320, gradient norm: 0.000215179650587729
# epoch 4340, gradient norm: 0.00021392430098823587
# epoch 4360, gradient norm: 0.00021267956605055673
# epoch 4380, gradient norm: 0.00021144530677366134
# epoch 4400, gradient norm: 0.00021022138667138295
# epoch 4420, gradient norm: 0.00020900767171581593
# epoch 4440, gradient norm: 0.00020780403028228202
# epoch 4460, gradient norm: 0.00020661033309581436
# epoch 4480, gradient norm: 0.00020542645317909867
# epoch 4500, gradient norm: 0.00020425226580182877
# epoch 4520, gradient norm: 0.00020308764843142763
# epoch 4540, gradient norm: 0.00020193248068508464
# epoch 4560, gradient norm: 0.00020078664428306678
# epoch 4580, gradient norm: 0.00019965002300326517
# epoch 4600, gradient norm: 0.00019852250263692893
# epoch 4620, gradient norm: 0.00019740397094555488
# epoch 4640, gradient norm: 0.00019629431761889154
# epoch 4660, gradient norm: 0.00019519343423402252
# epoch 4680, gradient norm: 0.0001941012142154955
# epoch 4700, gradient norm: 0.00019301755279646493
# epoch 4720, gradient norm: 0.00019194234698081315
# epoch 4740, gradient norm: 0.0001908754955062214
# epoch 4760, gradient norm: 0.0001898168988081637
# epoch 4780, gradient norm: 0.00018876645898479235
# epoch 4800, gradient norm: 0.00018772407976268713
# epoch 4820, gradient norm: 0.0001866896664634466
# epoch 4840, gradient norm: 0.00018566312597109133
# epoch 4860, gradient norm: 0.00018464436670025724
# epoch 4880, gradient norm: 0.00018363329856515838
# epoch 4900, gradient norm: 0.00018262983294928741
# epoch 4920, gradient norm: 0.00018163388267584726
# epoch 4940, gradient norm: 0.00018064536197887786
# epoch 4960, gradient norm: 0.00017966418647506573
# epoch 4980, gradient norm: 0.00017869027313621808
# epoch 5000, gradient norm: 0.00017772354026237766
# epoch 5020, gradient norm: 0.0001767639074555643
# epoch 5040, gradient norm: 0.0001758112955941244
# epoch 5060, gradient norm: 0.00017486562680767072
# epoch 5080, gradient norm: 0.00017392682445259785
# epoch 5100, gradient norm: 0.00017299481308815552
# epoch 5120, gradient norm: 0.00017206951845306825
# epoch 5140, gradient norm: 0.00017115086744268201
# epoch 5160, gradient norm: 0.00017023878808662544
# epoch 5180, gradient norm: 0.0001693332095269762
# epoch 5200, gradient norm: 0.0001684340619969109
# epoch 5220, gradient norm: 0.00016754127679983322
# epoch 5240, gradient norm: 0.00016665478628896354
# epoch 5260, gradient norm: 0.00016577452384738058
# epoch 5280, gradient norm: 0.00016490042386850006
# epoch 5300, gradient norm: 0.00016403242173698357
# epoch 5320, gradient norm: 0.00016317045381006377
# epoch 5340, gradient norm: 0.00016231445739927416
# epoch 5360, gradient norm: 0.0001614643707525777
# epoch 5380, gradient norm: 0.00016062013303687984
# epoch 5400, gradient norm: 0.000159781684320918
# epoch 5420, gradient norm: 0.0001589489655585191
# epoch 5440, gradient norm: 0.0001581219185722149
# epoch 5460, gradient norm: 0.00015730048603720557
# epoch 5480, gradient norm: 0.00015648461146566586
# epoch 5500, gradient norm: 0.00015567423919138245
# epoch 5520, gradient norm: 0.00015486931435471448
# epoch 5540, gradient norm: 0.00015406978288787403
# epoch 5560, gradient norm: 0.00015327559150051212
# epoch 5580, gradient norm: 0.00015248668766560788
# epoch 5600, gradient norm: 0.00015170301960565233
# epoch 5620, gradient norm: 0.00015092453627911775
# epoch 5640, gradient norm: 0.00015015118736721143
# epoch 5660, gradient norm: 0.0001493829232608983
# epoch 5680, gradient norm: 0.00014861969504819628
# epoch 5700, gradient norm: 0.00014786145450172857
# epoch 5720, gradient norm: 0.00014710815406653534
# epoch 5740, gradient norm: 0.00014635974684813183
# epoch 5760, gradient norm: 0.0001456161866008113
# epoch 5780, gradient norm: 0.0001448774277161863
# epoch 5800, gradient norm: 0.00014414342521196257
# epoch 5820, gradient norm: 0.00014341413472093983
# epoch 5840, gradient norm: 0.00014268951248023516
# epoch 5860, gradient norm: 0.0001419695153207232
# epoch 5880, gradient norm: 0.00014125410065669023
# epoch 5900, gradient norm: 0.00014054322647569277
# epoch 5920, gradient norm: 0.0001398368513286226
# epoch 5940, gradient norm: 0.00013913493431996716
# epoch 5960, gradient norm: 0.00013843743509826692
# epoch 5980, gradient norm: 0.0001377443138467594
# epoch 6000, gradient norm: 0.00013705553127420984
# epoch 6020, gradient norm: 0.0001363710486059255
# epoch 6040, gradient norm: 0.0001356908275749434
# epoch 6060, gradient norm: 0.00013501483041339514
# epoch 6080, gradient norm: 0.00013434301984403935
# epoch 6100, gradient norm: 0.000133675359071961
# epoch 6120, gradient norm: 0.00013301181177643312
# epoch 6140, gradient norm: 0.000132352342102938
# epoch 6160, gradient norm: 0.00013169691465534248
# epoch 6180, gradient norm: 0.00013104549448822748
# epoch 6200, gradient norm: 0.00013039804709936433
# epoch 6220, gradient norm: 0.00012975453842233896
# epoch 6240, gradient norm: 0.0001291149348193155
# epoch 6260, gradient norm: 0.00012847920307394457
# epoch 6280, gradient norm: 0.00012784731038440272
# epoch 6300, gradient norm: 0.00012721922435656886
# epoch 6320, gradient norm: 0.00012659491299733103
# epoch 6340, gradient norm: 0.0001259743447080211
# epoch 6360, gradient norm: 0.00012535748827797397
# epoch 6380, gradient norm: 0.00012474431287821055
# epoch 6400, gradient norm: 0.0001241347880552425
# epoch 6420, gradient norm: 0.00012352888372499038
# epoch 6440, gradient norm: 0.000122926570166822
# epoch 6460, gradient norm: 0.0001223278180176995
# epoch 6480, gradient norm: 0.0001217325982664397
# epoch 6500, gradient norm: 0.00012114088224808125
# epoch 6520, gradient norm: 0.0001205526416383584
# epoch 6540, gradient norm: 0.00011996784844827798
# epoch 6560, gradient norm: 0.00011938647501879813
# epoch 6580, gradient norm: 0.00011880849401560726
# epoch 6600, gradient norm: 0.00011823387842399983
# epoch 6620, gradient norm: 0.00011766260154384748
# epoch 6640, gradient norm: 0.0001170946369846633
# epoch 6660, gradient norm: 0.00011652995866076016
# epoch 6680, gradient norm: 0.000115968540786496
# epoch 6700, gradient norm: 0.00011541035787160691
# epoch 6720, gradient norm: 0.00011485538471662983
# epoch 6740, gradient norm: 0.00011430359640840502
# epoch 6760, gradient norm: 0.00011375496831566537
# epoch 6780, gradient norm: 0.00011320947608470274
# epoch 6800, gradient norm: 0.00011266709563511822
# epoch 6820, gradient norm: 0.00011212780315564493
# epoch 6840, gradient norm: 0.00011159157510005141
# epoch 6860, gradient norm: 0.00011105838818311801
# epoch 6880, gradient norm: 0.00011052821937668598
# epoch 6900, gradient norm: 0.00011000104590577811
# epoch 6920, gradient norm: 0.00010947684524479139
# epoch 6940, gradient norm: 0.00010895559511375594
# epoch 6960, gradient norm: 0.00010843727347466448
# epoch 6980, gradient norm: 0.00010792185852786547
# epoch 7000, gradient norm: 0.00010740932870852061
# epoch 7020, gradient norm: 0.00010689966268312945
# epoch 7040, gradient norm: 0.00010639283934611324
# epoch 7060, gradient norm: 0.00010588883781645846
# epoch 7080, gradient norm: 0.00010538763743442538
# epoch 7100, gradient norm: 0.00010488921775831063
# epoch 7120, gradient norm: 0.0001043935585612679
# epoch 7140, gradient norm: 0.00010390063982818774
# epoch 7160, gradient norm: 0.00010341044175262973
# epoch 7180, gradient norm: 0.00010292294473380945
# epoch 7200, gradient norm: 0.00010243812937364032
# epoch 7220, gradient norm: 0.00010195597647382477
# epoch 7240, gradient norm: 0.00010147646703299819
# epoch 7260, gradient norm: 0.00010099958224392259
# epoch 7280, gradient norm: 0.00010052530349073026
# epoch 7300, gradient norm: 0.0001000536123462126
# epoch 7320, gradient norm: 9.958449056916014e-05
# epoch 7340, gradient norm: 9.911792010174513e-05
# epoch 7360, gradient norm: 9.865388306695224e-05
# epoch 7380, gradient norm: 9.819236176605277e-05
# epoch 7400, gradient norm: 9.773333867612142e-05
# epoch 7420, gradient norm: 9.727679644759746e-05
# epoch 7440, gradient norm: 9.682271790188735e-05
# epoch 7460, gradient norm: 9.637108602900765e-05
# epoch 7480, gradient norm: 9.592188398527095e-05
# epoch 7500, gradient norm: 9.547509509100597e-05
# epoch 7520, gradient norm: 9.503070282832362e-05
# epoch 7540, gradient norm: 9.458869083891561e-05
# epoch 7560, gradient norm: 9.414904292189223e-05
# epoch 7580, gradient norm: 9.371174303165736e-05
# epoch 7600, gradient norm: 9.327677527581905e-05
# epoch 7620, gradient norm: 9.284412391313439e-05
# epoch 7640, gradient norm: 9.241377335149046e-05
# epoch 7660, gradient norm: 9.198570814591842e-05
# epoch 7680, gradient norm: 9.155991299664126e-05
# epoch 7700, gradient norm: 9.113637274715239e-05
# epoch 7720, gradient norm: 9.071507238233025e-05
# epoch 7740, gradient norm: 9.029599702658021e-05
# epoch 7760, gradient norm: 8.987913194200874e-05
# epoch 7780, gradient norm: 8.946446252662935e-05
# epoch 7800, gradient norm: 8.905197431259635e-05
# epoch 7820, gradient norm: 8.864165296446801e-05
# epoch 7840, gradient norm: 8.82334842774994e-05
# epoch 7860, gradient norm: 8.782745417596131e-05
# epoch 7880, gradient norm: 8.74235487114891e-05
# epoch 7900, gradient norm: 8.70217540614567e-05
# epoch 7920, gradient norm: 8.662205652737796e-05
# epoch 7940, gradient norm: 8.622444253333366e-05
# epoch 7960, gradient norm: 8.582889862442393e-05
# epoch 7980, gradient norm: 8.5435411465247e-05
# epoch 8000, gradient norm: 8.504396783839968e-05
# epoch 8020, gradient norm: 8.465455464300595e-05
# epoch 8040, gradient norm: 8.426715889326517e-05
# epoch 8060, gradient norm: 8.388176771702631e-05
# epoch 8080, gradient norm: 8.349836835438425e-05
# epoch 8100, gradient norm: 8.311694815629844e-05
# epoch 8120, gradient norm: 8.273749458323265e-05
# epoch 8140, gradient norm: 8.235999520381742e-05
# epoch 8160, gradient norm: 8.198443769353375e-05
# epoch 8180, gradient norm: 8.161080983341669e-05
# epoch 8200, gradient norm: 8.123909950878074e-05
# epoch 8220, gradient norm: 8.086929470796315e-05
# epoch 8240, gradient norm: 8.050138352108838e-05
# epoch 8260, gradient norm: 8.01353541388534e-05
# epoch 8280, gradient norm: 7.977119485132727e-05
# epoch 8300, gradient norm: 7.940889404677507e-05
# epoch 8320, gradient norm: 7.904844021049496e-05
# epoch 8340, gradient norm: 7.868982192367741e-05
# epoch 8360, gradient norm: 7.833302786227939e-05
# epoch 8380, gradient norm: 7.797804679591601e-05
# epoch 8400, gradient norm: 7.762486758677171e-05
# epoch 8420, gradient norm: 7.727347918852426e-05
# epoch 8440, gradient norm: 7.69238706452879e-05
# epoch 8460, gradient norm: 7.657603109057275e-05
# epoch 8480, gradient norm: 7.622994974625754e-05
# epoch 8500, gradient norm: 7.588561592158076e-05
# epoch 8520, gradient norm: 7.55430190121442e-05
# epoch 8540, gradient norm: 7.520214849893573e-05
# epoch 8560, gradient norm: 7.486299394736062e-05
# epoch 8580, gradient norm: 7.452554500629374e-05
# epoch 8600, gradient norm: 7.418979140714112e-05
# epoch 8620, gradient norm: 7.385572296291832e-05
# epoch 8640, gradient norm: 7.352332956734094e-05
# epoch 8660, gradient norm: 7.319260119392946e-05
# epoch 8680, gradient norm: 7.286352789512709e-05
# epoch 8700, gradient norm: 7.253609980143022e-05
# epoch 8720, gradient norm: 7.221030712053206e-05
# epoch 8740, gradient norm: 7.188614013647875e-05
# epoch 8760, gradient norm: 7.156358920883742e-05
# epoch 8780, gradient norm: 7.124264477187709e-05
# epoch 8800, gradient norm: 7.092329733376022e-05
# epoch 8820, gradient norm: 7.060553747574836e-05
# epoch 8840, gradient norm: 7.028935585141607e-05
# epoch 8860, gradient norm: 6.997474318587833e-05
# epoch 8880, gradient norm: 6.966169027502789e-05
# epoch 8900, gradient norm: 6.935018798478535e-05
# epoch 8920, gradient norm: 6.904022725035734e-05
# epoch 8940, gradient norm: 6.873179907550737e-05
# epoch 8960, gradient norm: 6.842489453183533e-05
# epoch 8980, gradient norm: 6.811950475806921e-05
# epoch 9000, gradient norm: 6.781562095936458e-05
# epoch 9020, gradient norm: 6.751323440661553e-05
# epoch 9040, gradient norm: 6.72123364357737e-05
# epoch 9060, gradient norm: 6.691291844717968e-05
# epoch 9080, gradient norm: 6.66149719048998e-05
# epoch 9100, gradient norm: 6.631848833607572e-05
# epoch 9120, gradient norm: 6.602345933027911e-05
# epoch 9140, gradient norm: 6.572987653888104e-05
# epoch 9160, gradient norm: 6.543773167442365e-05
# epoch 9180, gradient norm: 6.514701651000371e-05
# epoch 9200, gradient norm: 6.485772287866565e-05
# epoch 9220, gradient norm: 6.456984267280011e-05
# epoch 9240, gradient norm: 6.428336784355197e-05
# epoch 9260, gradient norm: 6.399829040023711e-05
# epoch 9280, gradient norm: 6.371460240976543e-05
# epoch 9300, gradient norm: 6.343229599607387e-05
# epoch 9320, gradient norm: 6.315136333956288e-05
# epoch 9340, gradient norm: 6.287179667654658e-05
# epoch 9360, gradient norm: 6.259358829870424e-05
# epoch 9380, gradient norm: 6.231673055254282e-05
# epoch 9400, gradient norm: 6.204121583886571e-05
# epoch 9420, gradient norm: 6.176703661224695e-05
# epoch 9440, gradient norm: 6.149418538051417e-05
# epoch 9460, gradient norm: 6.122265470423832e-05
# epoch 9480, gradient norm: 6.0952437196229125e-05
# epoch 9500, gradient norm: 6.068352552103696e-05
# epoch 9520, gradient norm: 6.041591239446273e-05
# epoch 9540, gradient norm: 6.014959058307126e-05
# epoch 9560, gradient norm: 5.988455290371512e-05
# epoch 9580, gradient norm: 5.962079222306008e-05
# epoch 9600, gradient norm: 5.93583014571197e-05
# epoch 9620, gradient norm: 5.9097073570795134e-05
# epoch 9640, gradient norm: 5.8837101577420255e-05
# epoch 9660, gradient norm: 5.857837853831245e-05
# epoch 9680, gradient norm: 5.832089756233002e-05
# epoch 9700, gradient norm: 5.806465180543472e-05
# epoch 9720, gradient norm: 5.7809634470259115e-05
# epoch 9740, gradient norm: 5.7555838805680276e-05
# epoch 9760, gradient norm: 5.730325810639845e-05
# epoch 9780, gradient norm: 5.7051885712520714e-05
# epoch 9800, gradient norm: 5.680171500915095e-05
# epoch 9820, gradient norm: 5.655273942598219e-05
# epoch 9840, gradient norm: 5.6304952436897953e-05
# epoch 9860, gradient norm: 5.605834755957352e-05
# epoch 9880, gradient norm: 5.58129183550881e-05
# epoch 9900, gradient norm: 5.556865842753557e-05
# epoch 9920, gradient norm: 5.5325561423644516e-05
# epoch 9940, gradient norm: 5.5083621032400135e-05
# epoch 9960, gradient norm: 5.484283098467265e-05
# epoch 9980, gradient norm: 5.460318505284841e-05
# epoch 10000, gradient norm: 5.436467705046706e-05
# epoch 10020, gradient norm: 5.412730083186154e-05
# epoch 10040, gradient norm: 5.389105029180338e-05
# epoch 10060, gradient norm: 5.365591936515211e-05
# epoch 10080, gradient norm: 5.342190202650775e-05
# epoch 10100, gradient norm: 5.318899228986924e-05
# epoch 10120, gradient norm: 5.295718420829539e-05
# epoch 10140, gradient norm: 5.27264718735702e-05
# epoch 10160, gradient norm: 5.2496849415872675e-05
# epoch 10180, gradient norm: 5.2268311003448514e-05
# epoch 10200, gradient norm: 5.204085084228887e-05
# epoch 10220, gradient norm: 5.18144631758098e-05
# epoch 10240, gradient norm: 5.158914228453719e-05
# epoch 10260, gradient norm: 5.136488248579406e-05
# epoch 10280, gradient norm: 5.114167813339242e-05
# epoch 10300, gradient norm: 5.091952361732841e-05
# epoch 10320, gradient norm: 5.069841336348022e-05
# epoch 10340, gradient norm: 5.04783418333111e-05
# epoch 10360, gradient norm: 5.025930352357276e-05
# epoch 10380, gradient norm: 5.004129296601531e-05
# epoch 10400, gradient norm: 4.9824304727099046e-05
# epoch 10420, gradient norm: 4.960833340770844e-05
# epoch 10440, gradient norm: 4.939337364287165e-05
# epoch 10460, gradient norm: 4.917942010147997e-05
# epoch 10480, gradient norm: 4.896646748601477e-05
# epoch 10500, gradient norm: 4.875451053227203e-05
# epoch 10520, gradient norm: 4.854354400909512e-05
# epoch 10540, gradient norm: 4.833356271810692e-05
# epoch 10560, gradient norm: 4.812456149344602e-05
# epoch 10580, gradient norm: 4.791653520150589e-05
# epoch 10600, gradient norm: 4.7709478740677736e-05
# epoch 10620, gradient norm: 4.7503387041093594e-05
# epoch 10640, gradient norm: 4.729825506437512e-05
# epoch 10660, gradient norm: 4.7094077803383046e-05
# epoch 10680, gradient norm: 4.68908502819703e-05
# epoch 10700, gradient norm: 4.6688567554737146e-05
# epoch 10720, gradient norm: 4.648722470678925e-05
# epoch 10740, gradient norm: 4.628681685349864e-05
# epoch 10760, gradient norm: 4.6087339140266774e-05
# epoch 10780, gradient norm: 4.588878674228911e-05
# epoch 10800, gradient norm: 4.5691154864324937e-05
# epoch 10820, gradient norm: 4.549443874046603e-05
# epoch 10840, gradient norm: 4.5298633633910734e-05
# epoch 10860, gradient norm: 4.5103734836738617e-05
# epoch 10880, gradient norm: 4.490973766968799e-05
# epoch 10900, gradient norm: 4.4716637481936444e-05
# epoch 10920, gradient norm: 4.4524429650881336e-05
# epoch 10940, gradient norm: 4.4333109581925643e-05
# epoch 10960, gradient norm: 4.414267270826385e-05
# epoch 10980, gradient norm: 4.395311449066992e-05
# epoch 11000, gradient norm: 4.376443041728977e-05
# epoch 11020, gradient norm: 4.357661600343228e-05
# epoch 11040, gradient norm: 4.3389666791365674e-05
# epoch 11060, gradient norm: 4.320357835011365e-05
# epoch 11080, gradient norm: 4.30183462752551e-05
# epoch 11100, gradient norm: 4.283396618872465e-05
# epoch 11120, gradient norm: 4.2650433738615824e-05
# epoch 11140, gradient norm: 4.246774459898683e-05
# epoch 11160, gradient norm: 4.2285894469666045e-05
# epoch 11180, gradient norm: 4.21048790760614e-05
# epoch 11200, gradient norm: 4.1924694168971796e-05
# epoch 11220, gradient norm: 4.174533552439878e-05
# epoch 11240, gradient norm: 4.1566798943361374e-05
# epoch 11260, gradient norm: 4.138908025171122e-05
# epoch 11280, gradient norm: 4.121217529995205e-05
# epoch 11300, gradient norm: 4.103607996305824e-05
# epoch 11320, gradient norm: 4.0860790140296784e-05
# epoch 11340, gradient norm: 4.0686301755050326e-05
# epoch 11360, gradient norm: 4.051261075464135e-05
# epoch 11380, gradient norm: 4.033971311015924e-05
# epoch 11400, gradient norm: 4.0167604816289035e-05
# epoch 11420, gradient norm: 3.999628189114002e-05
# epoch 11440, gradient norm: 3.982574037607731e-05
# epoch 11460, gradient norm: 3.96559763355557e-05
# epoch 11480, gradient norm: 3.948698585695294e-05
# epoch 11500, gradient norm: 3.931876505040722e-05
# epoch 11520, gradient norm: 3.915131004865268e-05
# epoch 11540, gradient norm: 3.898461700686089e-05
# epoch 11560, gradient norm: 3.8818682102479825e-05
# epoch 11580, gradient norm: 3.865350153507635e-05
# epoch 11600, gradient norm: 3.848907152618015e-05
# epoch 11620, gradient norm: 3.832538831912791e-05
# epoch 11640, gradient norm: 3.816244817891064e-05
# epoch 11660, gradient norm: 3.8000247392020154e-05
# epoch 11680, gradient norm: 3.783878226629957e-05
# epoch 11700, gradient norm: 3.767804913079316e-05
# epoch 11720, gradient norm: 3.751804433559799e-05
# epoch 11740, gradient norm: 3.735876425171807e-05
# epoch 11760, gradient norm: 3.72002052709171e-05
# epoch 11780, gradient norm: 3.704236380557691e-05
# epoch 11800, gradient norm: 3.6885236288551933e-05
# epoch 11820, gradient norm: 3.672881917302985e-05
# epoch 11840, gradient norm: 3.6573108932389215e-05
# epoch 11860, gradient norm: 3.641810206006179e-05
# epoch 11880, gradient norm: 3.626379506939402e-05
# epoch 11900, gradient norm: 3.611018449351151e-05
# epoch 11920, gradient norm: 3.595726688518089e-05
# epoch 11940, gradient norm: 3.580503881667868e-05
# epoch 11960, gradient norm: 3.565349687965624e-05
# epoch 11980, gradient norm: 3.550263768500868e-05
# epoch 12000, gradient norm: 3.5352457862743125e-05

# %% [markdown]
# # Part VIII: DatasetStudent Dataset

# %%
m = loadmat('LSTUDENT_DATA1.mat')
A = np.array(m['A']).astype("float")
b = np.array(m['b']).astype("float")
b[np.where(b == 0)[0]] = -1
c = np.array(m['c']).astype('float')
c[np.where(c == 0)[0]] = -1

# %%
A.shape
# Out:
# (20427, 379)

# %% [markdown]
# ## Part VIII-I: PAN Solution

# %%
# PAN(5%)
params = np.zeros(380).reshape(-1, 1)
params_pan_5, gradients_pan_5, time_pan_5 = PAN(params, A, b, c, 0.0001, 0.0001, 1.0, ratio=0.05, epochs=100, lr=0.5)
# Out:
# epoch 0, gradient norm: 0.5935822488611634
# epoch 5, gradient norm: 0.5108317031099475
# epoch 10, gradient norm: 0.014149767129513071
# epoch 15, gradient norm: 0.0003742593832350471
# epoch 20, gradient norm: 1.177985161439146e-05
# epoch 25, gradient norm: 3.67366790564919e-07
# epoch 30, gradient norm: 1.1609598110680183e-08
# epoch 35, gradient norm: 3.6696414274797555e-10
# epoch 40, gradient norm: 1.2231357063515421e-11
# epoch 45, gradient norm: 3.9901668851487933e-13
# epoch 50, gradient norm: 2.0123357811166924e-14
# epoch 55, gradient norm: 5.487038458799802e-16
# epoch 60, gradient norm: 4.730207025092572e-17
# epoch 65, gradient norm: 2.0441486367014674e-17
# epoch 70, gradient norm: 1.4401917081876896e-17
# epoch 75, gradient norm: 1.947115643183212e-17
# epoch 80, gradient norm: 1.9851168074515574e-17
# epoch 85, gradient norm: 1.4164860138435436e-17
# epoch 90, gradient norm: 7.274822667110992e-18
# epoch 95, gradient norm: 1.9642877251695356e-17
# epoch 100, gradient norm: 9.016111765771344e-18

# %%
# PAN(10%)
params = np.zeros(380).reshape(-1, 1)
params_pan_10, gradients_pan_10, time_pan_10 = PAN(params, A, b, c, 0.0001, 0.0001, 1.0, ratio=0.1, epochs=100, lr=0.5)
# Out:
# epoch 0, gradient norm: 0.5935822488611634
# epoch 5, gradient norm: 0.035409966950739405
# epoch 10, gradient norm: 0.0017696266871763567
# epoch 15, gradient norm: 5.2750675472587594e-05
# epoch 20, gradient norm: 1.4769711284142494e-06
# epoch 25, gradient norm: 3.8856403967741747e-08
# epoch 30, gradient norm: 1.1559898918201973e-09
# epoch 35, gradient norm: 3.415549923968517e-11
# epoch 40, gradient norm: 1.0152753135957461e-12
# epoch 45, gradient norm: 3.156295792971648e-14
# epoch 50, gradient norm: 9.63506363060443e-16
# epoch 55, gradient norm: 3.651578864688437e-17
# epoch 60, gradient norm: 1.4551529562032138e-17
# epoch 65, gradient norm: 2.5788779106619992e-17
# epoch 70, gradient norm: 2.0245594336328162e-17
# epoch 75, gradient norm: 3.1486558650340365e-17
# epoch 80, gradient norm: 1.4413837409048225e-17
# epoch 85, gradient norm: 2.5495829396252613e-17
# epoch 90, gradient norm: 9.029085806647482e-18
# epoch 95, gradient norm: 1.3703712329164486e-17
# epoch 100, gradient norm: 3.127525860780564e-17

# %%
# PAN(20%)
params = np.zeros(380).reshape(-1, 1)
params_pan_20, gradients_pan_20, time_pan_20 = PAN(params, A, b, c, 0.0001, 0.0001, 1.0, ratio=0.2, epochs=100, lr=0.5)
# Out:
# epoch 0, gradient norm: 0.5935822488611634
# epoch 5, gradient norm: 0.03537192259475998
# epoch 10, gradient norm: 0.0020151613479540446
# epoch 15, gradient norm: 6.832563775933332e-05
# epoch 20, gradient norm: 2.0095937974151372e-06
# epoch 25, gradient norm: 5.916914552767154e-08
# epoch 30, gradient norm: 1.7805533716255802e-09
# epoch 35, gradient norm: 5.331616450375534e-11
# epoch 40, gradient norm: 1.53788625291074e-12
# epoch 45, gradient norm: 4.795669970494562e-14
# epoch 50, gradient norm: 1.4617503814518958e-15
# epoch 55, gradient norm: 4.718807100966165e-17
# epoch 60, gradient norm: 8.931625511821976e-18
# epoch 65, gradient norm: 3.1329679223736474e-17
# epoch 70, gradient norm: 2.0096148454900752e-17
# epoch 75, gradient norm: 1.9271449357413552e-17
# epoch 80, gradient norm: 1.4724771772639162e-17
# epoch 85, gradient norm: 1.00156544020726e-17
# epoch 90, gradient norm: 5.337452900348058e-18
# epoch 95, gradient norm: 1.533638518706881e-17
# epoch 100, gradient norm: 2.559266867633418e-17

# %% [markdown]
# ## Part VIII-II: PANDA Solution

# %%
# PANDA(4)
params = np.zeros(380).reshape(-1, 1)
params_nt_4, gradients_nt_4, time_nt_4 = parallel_nt(params, A, b, c, 0.0001, 0.0001, 1.0, n_workers=4, epochs=200, lr=0.5)
# Out:
# epoch 0, gradient norm: 0.5935822198749362
# epoch 5, gradient norm: 0.035476823414181534
# epoch 10, gradient norm: 0.0020981297895746116
# epoch 15, gradient norm: 7.02164437425284e-05
# epoch 20, gradient norm: 2.1272287778385603e-06
# epoch 25, gradient norm: 6.446736695533603e-08
# epoch 30, gradient norm: 1.96037152460725e-09
# epoch 35, gradient norm: 5.979153423549333e-11
# epoch 40, gradient norm: 1.8283558712805793e-12
# epoch 45, gradient norm: 5.602856271051124e-14
# epoch 50, gradient norm: 1.7106863759507431e-15
# epoch 55, gradient norm: 5.552766877276874e-17
# epoch 60, gradient norm: 6.7643167276336596e-18
# epoch 65, gradient norm: 7.002781481831443e-18
# epoch 70, gradient norm: 8.271900497559508e-18
# epoch 75, gradient norm: 1.0738496248743002e-17
# epoch 80, gradient norm: 1.0682711731059565e-17
# epoch 85, gradient norm: 4.472814180418104e-18
# epoch 90, gradient norm: 1.2457723721359556e-17
# epoch 95, gradient norm: 1.1860084598069992e-17
# epoch 100, gradient norm: 1.4963970744164947e-17
# epoch 105, gradient norm: 1.5957277048635624e-17
# epoch 110, gradient norm: 2.3506645722614732e-17
# epoch 115, gradient norm: 7.504190751605569e-18
# epoch 120, gradient norm: 1.5099289345457624e-17
# epoch 125, gradient norm: 8.506901339404738e-18
# epoch 130, gradient norm: 1.309143324244065e-17
# epoch 135, gradient norm: 1.6558931842108065e-17
# epoch 140, gradient norm: 4.616907655354186e-18
# epoch 145, gradient norm: 9.817693092196698e-18
# epoch 150, gradient norm: 1.3133101750644453e-17
# epoch 155, gradient norm: 1.0631015997174829e-17
# epoch 160, gradient norm: 1.1904721907343932e-17
# epoch 165, gradient norm: 7.997434553864552e-18
# epoch 170, gradient norm: 1.6996977180877467e-17
# epoch 175, gradient norm: 1.352577563999308e-17
# epoch 180, gradient norm: 1.0701702871359867e-17
# epoch 185, gradient norm: 2.6258491893058395e-17
# epoch 190, gradient norm: 1.1496415520073426e-17
# epoch 195, gradient norm: 1.1035072937027744e-17
# epoch 200, gradient norm: 1.2733610102796019e-17

# %%
# PANDA(8)
params = np.zeros(380).reshape(-1, 1)
params_nt_8, gradients_nt_8, time_nt_8 = parallel_nt(params, A, b, c, 0.0001, 0.0001, 1.0, n_workers=8, epochs=200, lr=0.5)
# Out:
# epoch 0, gradient norm: 0.5935818200463516
# epoch 5, gradient norm: 0.03329249023724169
# epoch 10, gradient norm: 0.001791474027415085
# epoch 15, gradient norm: 5.574213822049723e-05
# epoch 20, gradient norm: 1.624300914435437e-06
# epoch 25, gradient norm: 4.807045118776536e-08
# epoch 30, gradient norm: 1.4423107707563097e-09
# epoch 35, gradient norm: 4.3728207012822e-11
# epoch 40, gradient norm: 1.3361396366588752e-12
# epoch 45, gradient norm: 4.1061969141013364e-14
# epoch 50, gradient norm: 1.2514841142351045e-15
# epoch 55, gradient norm: 3.857142719503152e-17
# epoch 60, gradient norm: 6.275797657998654e-18
# epoch 65, gradient norm: 1.3823564464287907e-17
# epoch 70, gradient norm: 8.920865016496103e-18
# epoch 75, gradient norm: 8.990173391998502e-18
# epoch 80, gradient norm: 7.083791614571127e-18
# epoch 85, gradient norm: 1.276513196826515e-17
# epoch 90, gradient norm: 1.114902297325981e-17
# epoch 95, gradient norm: 1.2763663397768102e-17
# epoch 100, gradient norm: 8.892644889617711e-18
# epoch 105, gradient norm: 1.1059475207929161e-17
# epoch 110, gradient norm: 1.3943998869881093e-17
# epoch 115, gradient norm: 6.094195930932403e-18
# epoch 120, gradient norm: 1.553779712097379e-17
# epoch 125, gradient norm: 1.0586554085017917e-17
# epoch 130, gradient norm: 1.1169593605786272e-17
# epoch 135, gradient norm: 1.1161005864017682e-17
# epoch 140, gradient norm: 1.2041637690830382e-17
# epoch 145, gradient norm: 9.417222715861052e-18
# epoch 150, gradient norm: 1.1872954524477212e-17
# epoch 155, gradient norm: 8.110972922165634e-18
# epoch 160, gradient norm: 6.8064493479864095e-18
# epoch 165, gradient norm: 1.6499747417866757e-17
# epoch 170, gradient norm: 1.1543573406486e-17
# epoch 175, gradient norm: 1.0273423705383925e-17
# epoch 180, gradient norm: 1.8569354467253543e-17
# epoch 185, gradient norm: 7.86760159632167e-18
# epoch 190, gradient norm: 1.1225694748235042e-17
# epoch 195, gradient norm: 1.5066802522606837e-17
# epoch 200, gradient norm: 1.0347438083744586e-17

# %%
# PANDA(16)
params = np.zeros(380).reshape(-1, 1)
params_nt_16, gradients_nt_16, time_nt_16 = parallel_nt(params, A, b, c, 0.0001, 0.0001, 1.0, n_workers=16, epochs=200, lr=0.5)
# Out:
# epoch 0, gradient norm: 0.59358158388404
# epoch 5, gradient norm: 0.030265523803204526
# epoch 10, gradient norm: 0.0013718853772173563
# epoch 15, gradient norm: 3.8306767464638494e-05
# epoch 20, gradient norm: 1.090120043529439e-06
# epoch 25, gradient norm: 3.251840413394253e-08
# epoch 30, gradient norm: 9.934944767986596e-10
# epoch 35, gradient norm: 3.0702867279203664e-11
# epoch 40, gradient norm: 9.540827150679302e-13
# epoch 45, gradient norm: 2.972621337723156e-14
# epoch 50, gradient norm: 9.535542663149847e-16
# epoch 55, gradient norm: 4.405873735851813e-17
# epoch 60, gradient norm: 2.875454741072235e-17
# epoch 65, gradient norm: 2.093862550517535e-17
# epoch 70, gradient norm: 2.176556250528426e-17
# epoch 75, gradient norm: 2.976799344648293e-17
# epoch 80, gradient norm: 1.7506196224139726e-17
# epoch 85, gradient norm: 2.0018756814422735e-17
# epoch 90, gradient norm: 1.5065784466991873e-17
# epoch 95, gradient norm: 3.003636334780766e-17
# epoch 100, gradient norm: 1.4972610529274337e-17
# epoch 105, gradient norm: 2.9959491812229737e-17
# epoch 110, gradient norm: 2.6994829686490068e-17
# epoch 115, gradient norm: 2.3002986979377782e-17
# epoch 120, gradient norm: 2.4799425794703162e-17
# epoch 125, gradient norm: 1.7825524120172915e-17
# epoch 130, gradient norm: 2.5500923844764007e-17
# epoch 135, gradient norm: 5.4809019931299626e-18
# epoch 140, gradient norm: 8.33499460552997e-18
# epoch 145, gradient norm: 1.1354590258218786e-17
# epoch 150, gradient norm: 1.3451302029186164e-17
# epoch 155, gradient norm: 1.2238954040087149e-17
# epoch 160, gradient norm: 5.6919036777877065e-18
# epoch 165, gradient norm: 1.1572813282285868e-17
# epoch 170, gradient norm: 2.1232952377169285e-17
# epoch 175, gradient norm: 1.2234291908129337e-17
# epoch 180, gradient norm: 1.3323737065322279e-17
# epoch 185, gradient norm: 1.9157358505678414e-17
# epoch 190, gradient norm: 7.3037174465043e-18
# epoch 195, gradient norm: 1.0493548729149965e-17
# epoch 200, gradient norm: 6.937430774331279e-18

# %%
# PANDA(32)
params = np.zeros(380).reshape(-1, 1)
params_nt_32, gradients_nt_32, time_nt_32 = parallel_nt(params, A, b, c, 0.0001, 0.0001, 1.0, n_workers=32, epochs=200, lr=0.4)
# Out:
# epoch 0, gradient norm: 0.5935810832392593
# epoch 5, gradient norm: 0.03818939791204123
# epoch 10, gradient norm: 0.0030242184890511025
# epoch 15, gradient norm: 0.00020642754704253282
# epoch 20, gradient norm: 1.4849144934682047e-05
# epoch 25, gradient norm: 1.1230935819222308e-06
# epoch 30, gradient norm: 8.646321176963655e-08
# epoch 35, gradient norm: 6.697695175691572e-09
# epoch 40, gradient norm: 5.200074748417337e-10
# epoch 45, gradient norm: 4.0409307861997594e-11
# epoch 50, gradient norm: 3.141337884549996e-12
# epoch 55, gradient norm: 2.442281046846603e-13
# epoch 60, gradient norm: 1.8982050785381036e-14
# epoch 65, gradient norm: 1.4764571643001524e-15
# epoch 70, gradient norm: 1.1898062939210272e-16
# epoch 75, gradient norm: 3.7328607419946856e-17
# epoch 80, gradient norm: 3.3020998884574836e-17
# epoch 85, gradient norm: 2.6965904959547528e-17
# epoch 90, gradient norm: 3.140439202105453e-17
# epoch 95, gradient norm: 3.3035943912007704e-17
# epoch 100, gradient norm: 3.824591370811746e-17
# epoch 105, gradient norm: 3.079937770160006e-17
# epoch 110, gradient norm: 2.2953171081193107e-17
# epoch 115, gradient norm: 3.040526385245748e-17
# epoch 120, gradient norm: 3.831755173101272e-17
# epoch 125, gradient norm: 2.7845199901616966e-17
# epoch 130, gradient norm: 3.3019377887409855e-17
# epoch 135, gradient norm: 2.6100984175686336e-17
# epoch 140, gradient norm: 2.794626161059438e-17
# epoch 145, gradient norm: 3.483181395315121e-17
# epoch 150, gradient norm: 2.5930722789992423e-17
# epoch 155, gradient norm: 3.3066342114615285e-17
# epoch 160, gradient norm: 3.1426778235671953e-17
# epoch 165, gradient norm: 2.9018917758638055e-17
# epoch 170, gradient norm: 2.9554033635669965e-17
# epoch 175, gradient norm: 2.7852595943033366e-17
# epoch 180, gradient norm: 2.759344331484258e-17
# epoch 185, gradient norm: 2.979733458898331e-17
# epoch 190, gradient norm: 3.1520644667138107e-17
# epoch 195, gradient norm: 3.2195856578401894e-17
# epoch 200, gradient norm: 3.5345160359701985e-17

# %%
# PANDA(64)
params = np.zeros(380).reshape(-1, 1)
params_nt_64, gradients_nt_64, time_nt_64 = parallel_nt(params, A, b, c, 0.0001, 0.0001, 1.0, n_workers=64, epochs=200, lr=0.2)
# Out:
# epoch 0, gradient norm: 0.5935813733684949
# epoch 5, gradient norm: 0.07081152870850359
# epoch 10, gradient norm: 0.011875206822518079
# epoch 15, gradient norm: 0.0023554467494712183
# epoch 20, gradient norm: 0.00048675310460731644
# epoch 25, gradient norm: 0.00010568594712874284
# epoch 30, gradient norm: 2.4152922292259893e-05
# epoch 35, gradient norm: 5.764127071344272e-06
# epoch 40, gradient norm: 1.4273221387000957e-06
# epoch 45, gradient norm: 3.6558678057043556e-07
# epoch 50, gradient norm: 9.677654931429782e-08
# epoch 55, gradient norm: 2.647211804502572e-08
# epoch 60, gradient norm: 7.47609566244863e-09
# epoch 65, gradient norm: 2.1748400230878437e-09
# epoch 70, gradient norm: 6.492790146120809e-10
# epoch 75, gradient norm: 1.980299828803943e-10
# epoch 80, gradient norm: 6.142698840864675e-11
# epoch 85, gradient norm: 1.930077259179825e-11
# epoch 90, gradient norm: 6.12300534481156e-12
# epoch 95, gradient norm: 1.956318590796504e-12
# epoch 100, gradient norm: 6.283363489720532e-13
# epoch 105, gradient norm: 2.0261362559339473e-13
# epoch 110, gradient norm: 6.553055315942664e-14
# epoch 115, gradient norm: 2.1250602739340282e-14
# epoch 120, gradient norm: 6.888163653827437e-15
# epoch 125, gradient norm: 2.2698106969923605e-15
# epoch 130, gradient norm: 7.2555481530986e-16
# epoch 135, gradient norm: 2.5944498617048304e-16
# epoch 140, gradient norm: 7.226822513383023e-17
# epoch 145, gradient norm: 5.3187195365958997e-17
# epoch 150, gradient norm: 2.0313938595438776e-17
# epoch 155, gradient norm: 3.397981592054647e-17
# epoch 160, gradient norm: 3.313246450104054e-17
# epoch 165, gradient norm: 3.651940984242855e-17
# epoch 170, gradient norm: 4.085897365830677e-17
# epoch 175, gradient norm: 5.2184128245304697e-17
# epoch 180, gradient norm: 4.180392433812761e-17
# epoch 185, gradient norm: 3.789427969887336e-17
# epoch 190, gradient norm: 4.479567414122376e-17
# epoch 195, gradient norm: 4.0058616227839505e-17
# epoch 200, gradient norm: 2.684785222209887e-17

# %%
# PANDA(128)
params = np.zeros(380).reshape(-1, 1)
params_nt_128, gradients_nt_128, time_nt_128 = parallel_nt(params, A, b, c, 0.0001, 0.0001, 1.0, n_workers=128, epochs=200, lr=0.1)
# Out:
# epoch 0, gradient norm: 0.5935888017611278
# epoch 5, gradient norm: 0.14661738798428223
# epoch 10, gradient norm: 0.0784335108554047
# epoch 15, gradient norm: 0.043572958222726166
# epoch 20, gradient norm: 0.02493680458817493
# epoch 25, gradient norm: 0.014512303878888145
# epoch 30, gradient norm: 0.008513772030894028
# epoch 35, gradient norm: 0.005012553726086108
# epoch 40, gradient norm: 0.0029558087743950267
# epoch 45, gradient norm: 0.0017442074299987916
# epoch 50, gradient norm: 0.0010295824600758817
# epoch 55, gradient norm: 0.0006078443389621999
# epoch 60, gradient norm: 0.00035888730089170327
# epoch 65, gradient norm: 0.0002119054187691513
# epoch 70, gradient norm: 0.00012512272452677424
# epoch 75, gradient norm: 7.388159634441808e-05
# epoch 80, gradient norm: 4.362545917905867e-05
# epoch 85, gradient norm: 2.5760015305948207e-05
# epoch 90, gradient norm: 1.5210861651078274e-05
# epoch 95, gradient norm: 8.981784492805382e-06
# epoch 100, gradient norm: 5.303618154932739e-06
# epoch 105, gradient norm: 3.1317166502182805e-06
# epoch 110, gradient norm: 1.8492393358964654e-06
# epoch 115, gradient norm: 1.091953461016523e-06
# epoch 120, gradient norm: 6.447857096899693e-07
# epoch 125, gradient norm: 3.807385831820527e-07
# epoch 130, gradient norm: 2.248218635502529e-07
# epoch 135, gradient norm: 1.3275483038581347e-07
# epoch 140, gradient norm: 7.839028262706766e-08
# epoch 145, gradient norm: 4.628861828724589e-08
# epoch 150, gradient norm: 2.7332935560193574e-08
# epoch 155, gradient norm: 1.6139809264584727e-08
# epoch 160, gradient norm: 9.530387713698218e-09
# epoch 165, gradient norm: 5.627594356339281e-09
# epoch 170, gradient norm: 3.323035905889309e-09
# epoch 175, gradient norm: 1.9622182818090246e-09
# epoch 180, gradient norm: 1.1586696252742757e-09
# epoch 185, gradient norm: 6.841824589760016e-10
# epoch 190, gradient norm: 4.040027160428445e-10
# epoch 195, gradient norm: 2.385594340403476e-10
# epoch 200, gradient norm: 1.408669065353883e-10

# %% [markdown]
# ## Part VIII-III: ProxSkip-VI-FL Solution

# %%
# ProxSkip(8)
params = np.zeros(380).reshape(-1, 1)
control = np.zeros(380).reshape(-1, 1)
params_ps_8, gradients_ps_8, time_ps_8 = proxskip(params, control, A, b, c, 0.0001, 0.0001, 1.0, n_workers=8, epochs=20000, lr=0.4, prob=0.4)

# %% [markdown]
# ## Part VIII-IV: EG Solution

# %%
# EG(8)
params = np.zeros(380).reshape(-1, 1)
params_extragrad_8, gradients_extragrad_8, time_extragrad_8 = parallel_extra(params, A, b, c, 0.0001, 0.0001, 1.0, n_workers=8, epochs=20000, lr=0.2)
# Out:
# epoch 0, gradient norm: 0.5935814763700317
# epoch 20, gradient norm: 0.16624564659849075
# epoch 40, gradient norm: 0.08399087430711
# epoch 60, gradient norm: 0.05277240077864303
# epoch 80, gradient norm: 0.03807473852742676
# epoch 100, gradient norm: 0.03011385225293302
# epoch 120, gradient norm: 0.02540702098834911
# epoch 140, gradient norm: 0.022418521245778384
# epoch 160, gradient norm: 0.02038535221513388
# epoch 180, gradient norm: 0.018905362850468656
# epoch 200, gradient norm: 0.01775944138150664
# epoch 220, gradient norm: 0.016825202311269247
# epoch 240, gradient norm: 0.016032592390025614
# epoch 260, gradient norm: 0.015340373217965239
# epoch 280, gradient norm: 0.014723426941642337
# epoch 300, gradient norm: 0.014165802169600965
# epoch 320, gradient norm: 0.01365685620216314
# epoch 340, gradient norm: 0.013189091515663541
# epoch 360, gradient norm: 0.012756930489801798
# epoch 380, gradient norm: 0.012356014549112893
# epoch 400, gradient norm: 0.011982798294219176
# epoch 420, gradient norm: 0.011634310209446533
# epoch 440, gradient norm: 0.011308007649078617
# epoch 460, gradient norm: 0.01100168531662349
# epoch 480, gradient norm: 0.01071341426651304
# epoch 500, gradient norm: 0.01044149855243982
# epoch 520, gradient norm: 0.010184442354074662
# epoch 540, gradient norm: 0.00994092361939989
# epoch 560, gradient norm: 0.00970977204023855
# epoch 580, gradient norm: 0.009489950152113345
# epoch 600, gradient norm: 0.009280536871484222
# epoch 620, gradient norm: 0.009080713056731747
# epoch 640, gradient norm: 0.008889748818933648
# epoch 660, gradient norm: 0.0087069923786284
# epoch 680, gradient norm: 0.008531860300343072
# epoch 700, gradient norm: 0.008363828956174319
# epoch 720, gradient norm: 0.008202427082497406
# epoch 740, gradient norm: 0.008047229304338559
# epoch 760, gradient norm: 0.00789785051190844
# epoch 780, gradient norm: 0.007753940983823402
# epoch 800, gradient norm: 0.007615182161637272
# epoch 820, gradient norm: 0.007481282990269348
# epoch 840, gradient norm: 0.0073519767485101155
# epoch 860, gradient norm: 0.007227018302823067
# epoch 880, gradient norm: 0.007106181726007323
# epoch 900, gradient norm: 0.006989258229871294
# epoch 920, gradient norm: 0.00687605436787061
# epoch 940, gradient norm: 0.006766390469699104
# epoch 960, gradient norm: 0.00666009927512922
# epoch 980, gradient norm: 0.006557024739032342
# epoch 1000, gradient norm: 0.006457020983531634
# epoch 1020, gradient norm: 0.006359951376714749
# epoch 1040, gradient norm: 0.006265687720323862
# epoch 1060, gradient norm: 0.00617410953140539
# epoch 1080, gradient norm: 0.006085103405096703
# epoch 1100, gradient norm: 0.005998562447601588
# epoch 1120, gradient norm: 0.005914385770004436
# epoch 1140, gradient norm: 0.005832478034934295
# epoch 1160, gradient norm: 0.005752749049248271
# epoch 1180, gradient norm: 0.005675113396888695
# epoch 1200, gradient norm: 0.005599490106905904
# epoch 1220, gradient norm: 0.005525802352350264
# epoch 1240, gradient norm: 0.0054539771763422295
# epoch 1260, gradient norm: 0.005383945242143669
# epoch 1280, gradient norm: 0.0053156406044915
# epoch 1300, gradient norm: 0.005249000499827188
# epoch 1320, gradient norm: 0.005183965153373069
# epoch 1340, gradient norm: 0.0051204776012771305
# epoch 1360, gradient norm: 0.005058483526278762
# epoch 1380, gradient norm: 0.004997931105545554
# epoch 1400, gradient norm: 0.00493877086950004
# epoch 1420, gradient norm: 0.0048809555706001775
# epoch 1440, gradient norm: 0.004824440061161651
# epoch 1460, gradient norm: 0.004769181179417063
# epoch 1480, gradient norm: 0.004715137643099237
# epoch 1500, gradient norm: 0.004662269949915518
# epoch 1520, gradient norm: 0.004610540284348841
# epoch 1540, gradient norm: 0.004559912430281221
# epoch 1560, gradient norm: 0.004510351688987316
# epoch 1580, gradient norm: 0.004461824802091204
# epoch 1600, gradient norm: 0.00441429987911918
# epoch 1620, gradient norm: 0.0043677463293162865
# epoch 1640, gradient norm: 0.00432213479742497
# epoch 1660, gradient norm: 0.004277437103151321
# epoch 1680, gradient norm: 0.004233626184068407
# epoch 1700, gradient norm: 0.004190676041727399
# epoch 1720, gradient norm: 0.004148561690766329
# epoch 1740, gradient norm: 0.0041072591108231435
# epoch 1760, gradient norm: 0.004066745201075033
# epoch 1780, gradient norm: 0.004026997737239701
# epoch 1800, gradient norm: 0.003987995330886494
# epoch 1820, gradient norm: 0.003949717390916618
# epoch 1840, gradient norm: 0.003912144087081695
# epoch 1860, gradient norm: 0.003875256315419207
# epoch 1880, gradient norm: 0.0038390356654917275
# epoch 1900, gradient norm: 0.0038034643893245994
# epoch 1920, gradient norm: 0.0037685253719437024
# epoch 1940, gradient norm: 0.0037342021034214917
# epoch 1960, gradient norm: 0.0037004786523453926
# epoch 1980, gradient norm: 0.0036673396406281906
# epoch 2000, gradient norm: 0.003634770219585097
# epoch 2020, gradient norm: 0.003602756047206916
# epoch 2040, gradient norm: 0.003571283266563044
# epoch 2060, gradient norm: 0.0035403384852721407
# epoch 2080, gradient norm: 0.003509908755982056
# epoch 2100, gradient norm: 0.003479981557804082
# epoch 2120, gradient norm: 0.003450544778649886
# epoch 2140, gradient norm: 0.003421586698422563
# epoch 2160, gradient norm: 0.0033930959730160064
# epoch 2180, gradient norm: 0.0033650616190795605
# epoch 2200, gradient norm: 0.0033374729995073425
# epoch 2220, gradient norm: 0.0033103198096139748
# epoch 2240, gradient norm: 0.003283592063960647
# epoch 2260, gradient norm: 0.0032572800837975145
# epoch 2280, gradient norm: 0.0032313744850902913
# epoch 2300, gradient norm: 0.003205866167100783
# epoch 2320, gradient norm: 0.0031807463014927348
# epoch 2340, gradient norm: 0.003156006321936013
# epoch 2360, gradient norm: 0.003131637914183584
# epoch 2380, gradient norm: 0.0031076330065972317
# epoch 2400, gradient norm: 0.0030839837610992164
# epoch 2420, gradient norm: 0.003060682564528363
# epoch 2440, gradient norm: 0.0030377220203802323
# epoch 2460, gradient norm: 0.0030150949409121323
# epoch 2480, gradient norm: 0.002992794339594777
# epoch 2500, gradient norm: 0.002970813423893365
# epoch 2520, gradient norm: 0.0029491455883618118
# epoch 2540, gradient norm: 0.0029277844080347025
# epoch 2560, gradient norm: 0.002906723632102369
# epoch 2580, gradient norm: 0.0028859571778553114
# epoch 2600, gradient norm: 0.002865479124884823
# epoch 2620, gradient norm: 0.0028452837095274907
# epoch 2640, gradient norm: 0.0028253653195418004
# epoch 2660, gradient norm: 0.00280571848900572
# epoch 2680, gradient norm: 0.0027863378934247455
# epoch 2700, gradient norm: 0.002767218345040408
# epoch 2720, gradient norm: 0.0027483547883297714
# epoch 2740, gradient norm: 0.00272974229568694
# epoch 2760, gradient norm: 0.002711376063278076
# epoch 2780, gradient norm: 0.0026932514070618203
# epoch 2800, gradient norm: 0.002675363758967487
# epoch 2820, gradient norm: 0.00265770866322373
# epoch 2840, gradient norm: 0.002640281772830795
# epoch 2860, gradient norm: 0.0026230788461698096
# epoch 2880, gradient norm: 0.002606095743742871
# epoch 2900, gradient norm: 0.0025893284250380474
# epoch 2920, gradient norm: 0.0025727729455136614
# epoch 2940, gradient norm: 0.0025564254536965337
# epoch 2960, gradient norm: 0.002540282188389128
# epoch 2980, gradient norm: 0.0025243394759807704
# epoch 3000, gradient norm: 0.0025085937278583655
# epoch 3020, gradient norm: 0.0024930414379122777
# epoch 3040, gradient norm: 0.002477679180133212
# epoch 3060, gradient norm: 0.0024625036062961873
# epoch 3080, gradient norm: 0.0024475114437278213
# epoch 3100, gradient norm: 0.002432699493153409
# epoch 3120, gradient norm: 0.0024180646266203556
# epoch 3140, gradient norm: 0.0024036037854947762
# epoch 3160, gradient norm: 0.002389313978528158
# epoch 3180, gradient norm: 0.0023751922799911712
# epoch 3200, gradient norm: 0.0023612358278718463
# epoch 3220, gradient norm: 0.002347441822135433
# epoch 3240, gradient norm: 0.0023338075230434395
# epoch 3260, gradient norm: 0.0023203302495294243
# epoch 3280, gradient norm: 0.0023070073776292285
# epoch 3300, gradient norm: 0.002293836338963472
# epoch 3320, gradient norm: 0.002280814619270209
# epoch 3340, gradient norm: 0.002267939756985749
# epoch 3360, gradient norm: 0.0022552093418717295
# epoch 3380, gradient norm: 0.0022426210136866362
# epoch 3400, gradient norm: 0.0022301724609000116
# epoch 3420, gradient norm: 0.0022178614194477207
# epoch 3440, gradient norm: 0.0022056856715266574
# epoch 3460, gradient norm: 0.002193643044427405
# epoch 3480, gradient norm: 0.0021817314094033893
# epoch 3500, gradient norm: 0.0021699486805751493
# epoch 3520, gradient norm: 0.0021582928138683902
# epoch 3540, gradient norm: 0.002146761805984574
# epoch 3560, gradient norm: 0.002135353693402821
# epoch 3580, gradient norm: 0.002124066551411978
# epoch 3600, gradient norm: 0.0021128984931717363
# epoch 3620, gradient norm: 0.002101847668801748
# epoch 3640, gradient norm: 0.0020909122644977166
# epoch 3660, gradient norm: 0.0020800905016735032
# epoch 3680, gradient norm: 0.0020693806361283046
# epoch 3700, gradient norm: 0.002058780957238021
# epoch 3720, gradient norm: 0.0020482897871699525
# epoch 3740, gradient norm: 0.0020379054801200128
# epoch 3760, gradient norm: 0.0020276264215716637
# epoch 3780, gradient norm: 0.002017451027575833
# epoch 3800, gradient norm: 0.0020073777440510793
# epoch 3820, gradient norm: 0.001997405046103314
# epoch 3840, gradient norm: 0.0019875314373644214
# epoch 3860, gradient norm: 0.0019777554493491368
# epoch 3880, gradient norm: 0.0019680756408295636
# epoch 3900, gradient norm: 0.001958490597226744
# epoch 3920, gradient norm: 0.001948998930018723
# epoch 3940, gradient norm: 0.0019395992761645595
# epoch 3960, gradient norm: 0.0019302902975437536
# epoch 3980, gradient norm: 0.0019210706804106052
# epoch 4000, gradient norm: 0.0019119391348630076
# epoch 4020, gradient norm: 0.0019028943943252168
# epoch 4040, gradient norm: 0.0018939352150441563
# epoch 4060, gradient norm: 0.0018850603755988145
# epoch 4080, gradient norm: 0.0018762686764223339
# epoch 4100, gradient norm: 0.001867558939336392
# epoch 4120, gradient norm: 0.0018589300070974858
# epoch 4140, gradient norm: 0.0018503807429547552
# epoch 4160, gradient norm: 0.0018419100302189905
# epoch 4180, gradient norm: 0.0018335167718424835
# epoch 4200, gradient norm: 0.0018251998900093824
# epoch 4220, gradient norm: 0.001816958325736254
# epoch 4240, gradient norm: 0.001808791038482518
# epoch 4260, gradient norm: 0.0018006970057704904
# epoch 4280, gradient norm: 0.001792675222814716
# epoch 4300, gradient norm: 0.0017847247021603539
# epoch 4320, gradient norm: 0.0017768444733303145
# epoch 4340, gradient norm: 0.00176903358248092
# epoch 4360, gradient norm: 0.0017612910920658223
# epoch 4380, gradient norm: 0.0017536160805079568
# epoch 4400, gradient norm: 0.0017460076418792843
# epoch 4420, gradient norm: 0.0017384648855881119
# epoch 4440, gradient norm: 0.0017309869360737761
# epoch 4460, gradient norm: 0.0017235729325084765
# epoch 4480, gradient norm: 0.0017162220285060587
# epoch 4500, gradient norm: 0.0017089333918375615
# epoch 4520, gradient norm: 0.0017017062041533298
# epoch 4540, gradient norm: 0.0016945396607115245
# epoch 4560, gradient norm: 0.001687432970112836
# epoch 4580, gradient norm: 0.0016803853540412572
# epoch 4600, gradient norm: 0.001673396047010723
# epoch 4620, gradient norm: 0.001666464296117486
# epoch 4640, gradient norm: 0.0016595893607980546
# epoch 4660, gradient norm: 0.0016527705125925494
# epoch 4680, gradient norm: 0.0016460070349133427
# epoch 4700, gradient norm: 0.0016392982228188315
# epoch 4720, gradient norm: 0.0016326433827922144
# epoch 4740, gradient norm: 0.0016260418325251345
# epoch 4760, gradient norm: 0.001619492900706078
# epoch 4780, gradient norm: 0.0016129959268133872
# epoch 4800, gradient norm: 0.0016065502609127753
# epoch 4820, gradient norm: 0.0016001552634592354
# epoch 4840, gradient norm: 0.0015938103051032185
# epoch 4860, gradient norm: 0.0015875147665009865
# epoch 4880, gradient norm: 0.0015812680381290208
# epoch 4900, gradient norm: 0.001575069520102393
# epoch 4920, gradient norm: 0.0015689186219970009
# epoch 4940, gradient norm: 0.0015628147626755627
# epoch 4960, gradient norm: 0.0015567573701172888
# epoch 4980, gradient norm: 0.0015507458812511342
# epoch 5000, gradient norm: 0.0015447797417925408
# epoch 5020, gradient norm: 0.0015388584060835918
# epoch 5040, gradient norm: 0.0015329813369364916
# epoch 5060, gradient norm: 0.0015271480054802865
# epoch 5080, gradient norm: 0.0015213578910107596
# epoch 5100, gradient norm: 0.0015156104808434084
# epoch 5120, gradient norm: 0.0015099052701694447
# epoch 5140, gradient norm: 0.0015042417619147406
# epoch 5160, gradient norm: 0.0014986194666016433
# epoch 5180, gradient norm: 0.0014930379022136094
# epoch 5200, gradient norm: 0.001487496594062568
# epoch 5220, gradient norm: 0.0014819950746589737
# epoch 5240, gradient norm: 0.0014765328835844688
# epoch 5260, gradient norm: 0.0014711095673670999
# epoch 5280, gradient norm: 0.0014657246793590342
# epoch 5300, gradient norm: 0.0014603777796167144
# epoch 5320, gradient norm: 0.001455068434783394
# epoch 5340, gradient norm: 0.0014497962179740008
# epoch 5360, gradient norm: 0.0014445607086622848
# epoch 5380, gradient norm: 0.0014393614925701755
# epoch 5400, gradient norm: 0.0014341981615593276
# epoch 5420, gradient norm: 0.0014290703135247846
# epoch 5440, gradient norm: 0.001423977552290723
# epoch 5460, gradient norm: 0.0014189194875082255
# epoch 5480, gradient norm: 0.0014138957345550462
# epoch 5500, gradient norm: 0.0014089059144373123
# epoch 5520, gradient norm: 0.001403949653693131
# epoch 5540, gradient norm: 0.0013990265842980518
# epoch 5560, gradient norm: 0.0013941363435723453
# epoch 5580, gradient norm: 0.0013892785740900668
# epoch 5600, gradient norm: 0.0013844529235898493
# epoch 5620, gradient norm: 0.001379659044887408
# epoch 5640, gradient norm: 0.0013748965957897043
# epoch 5660, gradient norm: 0.0013701652390107402
# epoch 5680, gradient norm: 0.00136546464208895
# epoch 5700, gradient norm: 0.0013607944773061469
# epoch 5720, gradient norm: 0.0013561544216080066
# epoch 5740, gradient norm: 0.001351544156526033
# epoch 5760, gradient norm: 0.0013469633681010003
# epoch 5780, gradient norm: 0.0013424117468078195
# epoch 5800, gradient norm: 0.0013378889874818087
# epoch 5820, gradient norm: 0.001333394789246342
# epoch 5840, gradient norm: 0.0013289288554418324
# epoch 5860, gradient norm: 0.0013244908935560445
# epoch 5880, gradient norm: 0.0013200806151556857
# epoch 5900, gradient norm: 0.0013156977358192664
# epoch 5920, gradient norm: 0.0013113419750711939
# epoch 5940, gradient norm: 0.0013070130563170798
# epoch 5960, gradient norm: 0.0013027107067802304
# epoch 5980, gradient norm: 0.0012984346574393057
# epoch 6000, gradient norm: 0.0012941846429671098
# epoch 6020, gradient norm: 0.0012899604016705
# epoch 6040, gradient norm: 0.0012857616754313923
# epoch 6060, gradient norm: 0.0012815882096488319
# epoch 6080, gradient norm: 0.0012774397531821146
# epoch 6100, gradient norm: 0.00127331605829494
# epoch 6120, gradient norm: 0.0012692168806005687
# epoch 6140, gradient norm: 0.0012651419790079656
# epoch 6160, gradient norm: 0.0012610911156689193
# epoch 6180, gradient norm: 0.001257064055926096
# epoch 6200, gradient norm: 0.0012530605682620401
# epoch 6220, gradient norm: 0.0012490804242490717
# epoch 6240, gradient norm: 0.0012451233985000844
# epoch 6260, gradient norm: 0.0012411892686202213
# epoch 6280, gradient norm: 0.0012372778151594017
# epoch 6300, gradient norm: 0.0012333888215656983
# epoch 6320, gradient norm: 0.0012295220741395337
# epoch 6340, gradient norm: 0.00122567736198869
# epoch 6360, gradient norm: 0.0012218544769841098
# epoch 6380, gradient norm: 0.001218053213716476
# epoch 6400, gradient norm: 0.001214273369453555
# epoch 6420, gradient norm: 0.0012105147440982901
# epoch 6440, gradient norm: 0.001206777140147625
# epoch 6460, gradient norm: 0.0012030603626520507
# epoch 6480, gradient norm: 0.0011993642191758557
# epoch 6500, gradient norm: 0.0011956885197580746
# epoch 6520, gradient norm: 0.0011920330768741053
# epoch 6540, gradient norm: 0.0011883977053980053
# epoch 6560, gradient norm: 0.001184782222565434
# epoch 6580, gradient norm: 0.0011811864479372358
# epoch 6600, gradient norm: 0.0011776102033636577
# epoch 6620, gradient norm: 0.0011740533129491807
# epoch 6640, gradient norm: 0.001170515603017956
# epoch 6660, gradient norm: 0.0011669969020798373
# epoch 6680, gradient norm: 0.0011634970407969991
# epoch 6700, gradient norm: 0.0011600158519511207
# epoch 6720, gradient norm: 0.0011565531704111356
# epoch 6740, gradient norm: 0.0011531088331015328
# epoch 6760, gradient norm: 0.0011496826789711952
# epoch 6780, gradient norm: 0.0011462745489627738
# epoch 6800, gradient norm: 0.0011428842859825764
# epoch 6820, gradient norm: 0.0011395117348709754
# epoch 6840, gradient norm: 0.0011361567423733077
# epoch 6860, gradient norm: 0.001132819157111276
# epoch 6880, gradient norm: 0.001129498829554827
# epoch 6900, gradient norm: 0.0011261956119945084
# epoch 6920, gradient norm: 0.00112290935851429
# epoch 6940, gradient norm: 0.0011196399249648397
# epoch 6960, gradient norm: 0.001116387168937253
# epoch 6980, gradient norm: 0.0011131509497372186
# epoch 7000, gradient norm: 0.0011099311283596207
# epoch 7020, gradient norm: 0.0011067275674635617
# epoch 7040, gradient norm: 0.0011035401313478047
# epoch 7060, gradient norm: 0.0011003686859266258
# epoch 7080, gradient norm: 0.0010972130987060656
# epoch 7100, gradient norm: 0.0010940732387605776
# epoch 7120, gradient norm: 0.0010909489767100642
# epoch 7140, gradient norm: 0.0010878401846972933
# epoch 7160, gradient norm: 0.0010847467363656839
# epoch 7180, gradient norm: 0.0010816685068374679
# epoch 7200, gradient norm: 0.001078605372692203
# epoch 7220, gradient norm: 0.0010755572119456448
# epoch 7240, gradient norm: 0.0010725239040289673
# epoch 7260, gradient norm: 0.0010695053297683195
# epoch 7280, gradient norm: 0.0010665013713647207
# epoch 7300, gradient norm: 0.0010635119123742869
# epoch 7320, gradient norm: 0.0010605368376887766
# epoch 7340, gradient norm: 0.0010575760335164563
# epoch 7360, gradient norm: 0.0010546293873632767
# epoch 7380, gradient norm: 0.0010516967880143595
# epoch 7400, gradient norm: 0.0010487781255157792
# epoch 7420, gradient norm: 0.0010458732911566445
# epoch 7440, gradient norm: 0.0010429821774514685
# epoch 7460, gradient norm: 0.0010401046781228261
# epoch 7480, gradient norm: 0.001037240688084291
# epoch 7500, gradient norm: 0.001034390103423646
# epoch 7520, gradient norm: 0.001031552821386365
# epoch 7540, gradient norm: 0.0010287287403593656
# epoch 7560, gradient norm: 0.0010259177598550134
# epoch 7580, gradient norm: 0.0010231197804953906
# epoch 7600, gradient norm: 0.0010203347039968145
# epoch 7620, gradient norm: 0.001017562433154603
# epoch 7640, gradient norm: 0.0010148028718280839
# epoch 7660, gradient norm: 0.0010120559249258418
# epoch 7680, gradient norm: 0.0010093214983912034
# epoch 7700, gradient norm: 0.0010065994991879516
# epoch 7720, gradient norm: 0.001003889835286265
# epoch 7740, gradient norm: 0.0010011924156488846
# epoch 7760, gradient norm: 0.0009985071502174947
# epoch 7780, gradient norm: 0.0009958339498993207
# epoch 7800, gradient norm: 0.000993172726553944
# epoch 7820, gradient norm: 0.000990523392980314
# epoch 7840, gradient norm: 0.0009878858629039742
# epoch 7860, gradient norm: 0.0009852600509644856
# epoch 7880, gradient norm: 0.0009826458727030443
# epoch 7900, gradient norm: 0.0009800432445503007
# epoch 7920, gradient norm: 0.0009774520838143601
# epoch 7940, gradient norm: 0.0009748723086689794
# epoch 7960, gradient norm: 0.0009723038381419415
# epoch 7980, gradient norm: 0.0009697465921036151
# epoch 8000, gradient norm: 0.00096720049125569
# epoch 8020, gradient norm: 0.0009646654571200876
# epoch 8040, gradient norm: 0.0009621414120280452
# epoch 8060, gradient norm: 0.0009596282791093667
# epoch 8080, gradient norm: 0.0009571259822818423
# epoch 8100, gradient norm: 0.0009546344462408286
# epoch 8120, gradient norm: 0.000952153596448991
# epoch 8140, gradient norm: 0.0009496833591262061
# epoch 8160, gradient norm: 0.0009472236612396122
# epoch 8180, gradient norm: 0.0009447744304938227
# epoch 8200, gradient norm: 0.00094233559532128
# epoch 8220, gradient norm: 0.000939907084872762
# epoch 8240, gradient norm: 0.0009374888290080339
# epoch 8260, gradient norm: 0.0009350807582866384
# epoch 8280, gradient norm: 0.000932682803958831
# epoch 8300, gradient norm: 0.0009302948979566511
# epoch 8320, gradient norm: 0.0009279169728851257
# epoch 8340, gradient norm: 0.0009255489620136143
# epoch 8360, gradient norm: 0.0009231907992672737
# epoch 8380, gradient norm: 0.0009208424192186615
# epoch 8400, gradient norm: 0.0009185037570794619
# epoch 8420, gradient norm: 0.0009161747486923354
# epoch 8440, gradient norm: 0.0009138553305228928
# epoch 8460, gradient norm: 0.0009115454396517902
# epoch 8480, gradient norm: 0.0009092450137669386
# epoch 8500, gradient norm: 0.0009069539911558362
# epoch 8520, gradient norm: 0.0009046723106980101
# epoch 8540, gradient norm: 0.0009023999118575719
# epoch 8560, gradient norm: 0.0009001367346758859
# epoch 8580, gradient norm: 0.0008978827197643447
# epoch 8600, gradient norm: 0.0008956378082972524
# epoch 8620, gradient norm: 0.0008934019420048126
# epoch 8640, gradient norm: 0.0008911750631662221
# epoch 8660, gradient norm: 0.0008889571146028651
# epoch 8680, gradient norm: 0.0008867480396716066
# epoch 8700, gradient norm: 0.0008845477822581862
# epoch 8720, gradient norm: 0.0008823562867707102
# epoch 8740, gradient norm: 0.0008801734981332363
# epoch 8760, gradient norm: 0.0008779993617794522
# epoch 8780, gradient norm: 0.0008758338236464509
# epoch 8800, gradient norm: 0.0008736768301685917
# epoch 8820, gradient norm: 0.0008715283282714527
# epoch 8840, gradient norm: 0.0008693882653658734
# epoch 8860, gradient norm: 0.0008672565893420794
# epoch 8880, gradient norm: 0.0008651332485638953
# epoch 8900, gradient norm: 0.0008630181918630428
# epoch 8920, gradient norm: 0.0008609113685335161
# epoch 8940, gradient norm: 0.0008588127283260426
# epoch 8960, gradient norm: 0.0008567222214426222
# epoch 8980, gradient norm: 0.0008546397985311455
# epoch 9000, gradient norm: 0.000852565410680087
# epoch 9020, gradient norm: 0.0008504990094132779
# epoch 9040, gradient norm: 0.0008484405466847493
# epoch 9060, gradient norm: 0.0008463899748736558
# epoch 9080, gradient norm: 0.0008443472467792614
# epoch 9100, gradient norm: 0.0008423123156160062
# epoch 9120, gradient norm: 0.0008402851350086368
# epoch 9140, gradient norm: 0.0008382656589874119
# epoch 9160, gradient norm: 0.0008362538419833661
# epoch 9180, gradient norm: 0.0008342496388236513
# epoch 9200, gradient norm: 0.0008322530047269372
# epoch 9220, gradient norm: 0.0008302638952988762
# epoch 9240, gradient norm: 0.0008282822665276377
# epoch 9260, gradient norm: 0.0008263080747794982
# epoch 9280, gradient norm: 0.0008243412767944961
# epoch 9300, gradient norm: 0.000822381829682149
# epoch 9320, gradient norm: 0.0008204296909172273
# epoch 9340, gradient norm: 0.0008184848183355889
# epoch 9360, gradient norm: 0.0008165471701300695
# epoch 9380, gradient norm: 0.0008146167048464337
# epoch 9400, gradient norm: 0.0008126933813793775
# epoch 9420, gradient norm: 0.0008107771589685883
# epoch 9440, gradient norm: 0.0008088679971948626
# epoch 9460, gradient norm: 0.0008069658559762686
# epoch 9480, gradient norm: 0.0008050706955643679
# epoch 9500, gradient norm: 0.0008031824765404921
# epoch 9520, gradient norm: 0.0008013011598120586
# epoch 9540, gradient norm: 0.0007994267066089493
# epoch 9560, gradient norm: 0.0007975590784799312
# epoch 9580, gradient norm: 0.0007956982372891272
# epoch 9600, gradient norm: 0.0007938441452125372
# epoch 9620, gradient norm: 0.0007919967647346025
# epoch 9640, gradient norm: 0.0007901560586448196
# epoch 9660, gradient norm: 0.0007883219900343981
# epoch 9680, gradient norm: 0.0007864945222929659
# epoch 9700, gradient norm: 0.0007846736191053136
# epoch 9720, gradient norm: 0.0007828592444481905
# epoch 9740, gradient norm: 0.0007810513625871357
# epoch 9760, gradient norm: 0.0007792499380733538
# epoch 9780, gradient norm: 0.0007774549357406378
# epoch 9800, gradient norm: 0.000775666320702325
# epoch 9820, gradient norm: 0.0007738840583482961
# epoch 9840, gradient norm: 0.0007721081143420179
# epoch 9860, gradient norm: 0.0007703384546176208
# epoch 9880, gradient norm: 0.0007685750453770128
# epoch 9900, gradient norm: 0.0007668178530870414
# epoch 9920, gradient norm: 0.0007650668444766788
# epoch 9940, gradient norm: 0.0007633219865342578
# epoch 9960, gradient norm: 0.0007615832465047334
# epoch 9980, gradient norm: 0.0007598505918869862
# epoch 10000, gradient norm: 0.0007581239904311584
# epoch 10020, gradient norm: 0.0007564034101360274
# epoch 10040, gradient norm: 0.0007546888192464064
# epoch 10060, gradient norm: 0.0007529801862505901
# epoch 10080, gradient norm: 0.0007512774798778219
# epoch 10100, gradient norm: 0.0007495806690958017
# epoch 10120, gradient norm: 0.0007478897231082204
# epoch 10140, gradient norm: 0.0007462046113523321
# epoch 10160, gradient norm: 0.0007445253034965522
# epoch 10180, gradient norm: 0.0007428517694380877
# epoch 10200, gradient norm: 0.0007411839793005988
# epoch 10220, gradient norm: 0.0007395219034318906
# epoch 10240, gradient norm: 0.0007378655124016312
# epoch 10260, gradient norm: 0.000736214776999104
# epoch 10280, gradient norm: 0.0007345696682309815
# epoch 10300, gradient norm: 0.000732930157319135
# epoch 10320, gradient norm: 0.0007312962156984657
# epoch 10340, gradient norm: 0.0007296678150147658
# epoch 10360, gradient norm: 0.000728044927122606
# epoch 10380, gradient norm: 0.0007264275240832516
# epoch 10400, gradient norm: 0.0007248155781626003
# epoch 10420, gradient norm: 0.0007232090618291487
# epoch 10440, gradient norm: 0.0007216079477519857
# epoch 10460, gradient norm: 0.0007200122087988048
# epoch 10480, gradient norm: 0.0007184218180339496
# epoch 10500, gradient norm: 0.0007168367487164754
# epoch 10520, gradient norm: 0.0007152569742982399
# epoch 10540, gradient norm: 0.0007136824684220161
# epoch 10560, gradient norm: 0.0007121132049196268
# epoch 10580, gradient norm: 0.0007105491578101042
# epoch 10600, gradient norm: 0.0007089903012978719
# epoch 10620, gradient norm: 0.0007074366097709467
# epoch 10640, gradient norm: 0.0007058880577991651
# epoch 10660, gradient norm: 0.00070434462013243
# epoch 10680, gradient norm: 0.0007028062716989801
# epoch 10700, gradient norm: 0.0007012729876036771
# epoch 10720, gradient norm: 0.000699744743126317
# epoch 10740, gradient norm: 0.0006982215137199608
# epoch 10760, gradient norm: 0.000696703275009284
# epoch 10780, gradient norm: 0.0006951900027889474
# epoch 10800, gradient norm: 0.000693681673021986
# epoch 10820, gradient norm: 0.0006921782618382206
# epoch 10840, gradient norm: 0.0006906797455326824
# epoch 10860, gradient norm: 0.0006891861005640629
# epoch 10880, gradient norm: 0.0006876973035531756
# epoch 10900, gradient norm: 0.0006862133312814445
# epoch 10920, gradient norm: 0.0006847341606893993
# epoch 10940, gradient norm: 0.0006832597688752002
# epoch 10960, gradient norm: 0.0006817901330931705
# epoch 10980, gradient norm: 0.0006803252307523519
# epoch 11000, gradient norm: 0.000678865039415075
# epoch 11020, gradient norm: 0.0006774095367955462
# epoch 11040, gradient norm: 0.0006759587007584521
# epoch 11060, gradient norm: 0.0006745125093175797
# epoch 11080, gradient norm: 0.0006730709406344509
# epoch 11100, gradient norm: 0.0006716339730169778
# epoch 11120, gradient norm: 0.0006702015849181274
# epoch 11140, gradient norm: 0.0006687737549346053
# epoch 11160, gradient norm: 0.0006673504618055542
# epoch 11180, gradient norm: 0.0006659316844112673
# epoch 11200, gradient norm: 0.0006645174017719149
# epoch 11220, gradient norm: 0.0006631075930462874
# epoch 11240, gradient norm: 0.0006617022375305546
# epoch 11260, gradient norm: 0.0006603013146570313
# epoch 11280, gradient norm: 0.0006589048039929667
# epoch 11300, gradient norm: 0.000657512685239342
# epoch 11320, gradient norm: 0.0006561249382296818
# epoch 11340, gradient norm: 0.0006547415429288803
# epoch 11360, gradient norm: 0.0006533624794320405
# epoch 11380, gradient norm: 0.0006519877279633258
# epoch 11400, gradient norm: 0.0006506172688748255
# epoch 11420, gradient norm: 0.0006492510826454307
# epoch 11440, gradient norm: 0.0006478891498797274
# epoch 11460, gradient norm: 0.0006465314513068953
# epoch 11480, gradient norm: 0.0006451779677796264
# epoch 11500, gradient norm: 0.000643828680273048
# epoch 11520, gradient norm: 0.0006424835698836635
# epoch 11540, gradient norm: 0.0006411426178283019
# epoch 11560, gradient norm: 0.0006398058054430814
# epoch 11580, gradient norm: 0.0006384731141823793
# epoch 11600, gradient norm: 0.00063714452561782
# epoch 11620, gradient norm: 0.0006358200214372686
# epoch 11640, gradient norm: 0.0006344995834438379
# epoch 11660, gradient norm: 0.0006331831935549067
# epoch 11680, gradient norm: 0.0006318708338011472
# epoch 11700, gradient norm: 0.0006305624863255639
# epoch 11720, gradient norm: 0.0006292581333825422
# epoch 11740, gradient norm: 0.000627957757336909
# epoch 11760, gradient norm: 0.0006266613406630006
# epoch 11780, gradient norm: 0.0006253688659437446
# epoch 11800, gradient norm: 0.0006240803158697456
# epoch 11820, gradient norm: 0.000622795673238388
# epoch 11840, gradient norm: 0.0006215149209529433
# epoch 11860, gradient norm: 0.0006202380420216881
# epoch 11880, gradient norm: 0.0006189650195570309
# epoch 11900, gradient norm: 0.0006176958367746514
# epoch 11920, gradient norm: 0.0006164304769926449
# epoch 11940, gradient norm: 0.0006151689236306773
# epoch 11960, gradient norm: 0.00061391116020915
# epoch 11980, gradient norm: 0.0006126571703483708
# epoch 12000, gradient norm: 0.0006114069377677381
# epoch 12020, gradient norm: 0.0006101604462849285
# epoch 12040, gradient norm: 0.000608917679815096
# epoch 12060, gradient norm: 0.0006076786223700796
# epoch 12080, gradient norm: 0.0006064432580576178
# epoch 12100, gradient norm: 0.000605211571080571
# epoch 12120, gradient norm: 0.0006039835457361534
# epoch 12140, gradient norm: 0.0006027591664151739
# epoch 12160, gradient norm: 0.0006015384176012793
# epoch 12180, gradient norm: 0.0006003212838702139
# epoch 12200, gradient norm: 0.0005991077498890772
# epoch 12220, gradient norm: 0.0005978978004155969
# epoch 12240, gradient norm: 0.0005966914202974062
# epoch 12260, gradient norm: 0.000595488594471327
# epoch 12280, gradient norm: 0.000594289307962664
# epoch 12300, gradient norm: 0.0005930935458845018
# epoch 12320, gradient norm: 0.0005919012934370137
# epoch 12340, gradient norm: 0.0005907125359067729
# epoch 12360, gradient norm: 0.0005895272586660747
# epoch 12380, gradient norm: 0.0005883454471722623
# epoch 12400, gradient norm: 0.0005871670869670616
# epoch 12420, gradient norm: 0.0005859921636759205
# epoch 12440, gradient norm: 0.0005848206630073581
# epoch 12460, gradient norm: 0.000583652570752317
# epoch 12480, gradient norm: 0.0005824878727835238
# epoch 12500, gradient norm: 0.0005813265550548553
# epoch 12520, gradient norm: 0.0005801686036007123
# epoch 12540, gradient norm: 0.0005790140045353965
# epoch 12560, gradient norm: 0.0005778627440524986
# epoch 12580, gradient norm: 0.000576714808424287
# epoch 12600, gradient norm: 0.0005755701840011059
# epoch 12620, gradient norm: 0.0005744288572107787
# epoch 12640, gradient norm: 0.0005732908145580157
# epoch 12660, gradient norm: 0.0005721560426238302
# epoch 12680, gradient norm: 0.0005710245280649584
# epoch 12700, gradient norm: 0.0005698962576132847
# epoch 12720, gradient norm: 0.0005687712180752749
# epoch 12740, gradient norm: 0.0005676493963314111
# epoch 12760, gradient norm: 0.0005665307793356367
# epoch 12780, gradient norm: 0.000565415354114802
# epoch 12800, gradient norm: 0.0005643031077681186
# epoch 12820, gradient norm: 0.0005631940274666191
# epoch 12840, gradient norm: 0.0005620881004526178
# epoch 12860, gradient norm: 0.0005609853140391814
# epoch 12880, gradient norm: 0.0005598856556096035
# epoch 12900, gradient norm: 0.0005587891126168814
# epoch 12920, gradient norm: 0.000557695672583202
# epoch 12940, gradient norm: 0.000556605323099429
# epoch 12960, gradient norm: 0.0005555180518245979
# epoch 12980, gradient norm: 0.0005544338464854114
# epoch 13000, gradient norm: 0.0005533526948757469
# epoch 13020, gradient norm: 0.0005522745848561605
# epoch 13040, gradient norm: 0.0005511995043534008
# epoch 13060, gradient norm: 0.0005501274413599262
# epoch 13080, gradient norm: 0.0005490583839334249
# epoch 13100, gradient norm: 0.000547992320196343
# epoch 13120, gradient norm: 0.0005469292383354123
# epoch 13140, gradient norm: 0.0005458691266011869
# epoch 13160, gradient norm: 0.0005448119733075809
# epoch 13180, gradient norm: 0.0005437577668314131
# epoch 13200, gradient norm: 0.0005427064956119517
# epoch 13220, gradient norm: 0.0005416581481504695
# epoch 13240, gradient norm: 0.0005406127130097976
# epoch 13260, gradient norm: 0.0005395701788138847
# epoch 13280, gradient norm: 0.0005385305342473623
# epoch 13300, gradient norm: 0.0005374937680551116
# epoch 13320, gradient norm: 0.0005364598690418355
# epoch 13340, gradient norm: 0.0005354288260716359
# epoch 13360, gradient norm: 0.0005344006280675892
# epoch 13380, gradient norm: 0.0005333752640113336
# epoch 13400, gradient norm: 0.0005323527229426549
# epoch 13420, gradient norm: 0.0005313329939590761
# epoch 13440, gradient norm: 0.0005303160662154537
# epoch 13460, gradient norm: 0.0005293019289235747
# epoch 13480, gradient norm: 0.0005282905713517587
# epoch 13500, gradient norm: 0.0005272819828244632
# epoch 13520, gradient norm: 0.0005262761527218924
# epoch 13540, gradient norm: 0.0005252730704796101
# epoch 13560, gradient norm: 0.0005242727255881539
# epoch 13580, gradient norm: 0.0005232751075926564
# epoch 13600, gradient norm: 0.0005222802060924664
# epoch 13620, gradient norm: 0.0005212880107407749
# epoch 13640, gradient norm: 0.0005202985112442447
# epoch 13660, gradient norm: 0.0005193116973626438
# epoch 13680, gradient norm: 0.0005183275589084786
# epoch 13700, gradient norm: 0.0005173460857466344
# epoch 13720, gradient norm: 0.0005163672677940187
# epoch 13740, gradient norm: 0.0005153910950192038
# epoch 13760, gradient norm: 0.0005144175574420761
# epoch 13780, gradient norm: 0.0005134466451334884
# epoch 13800, gradient norm: 0.0005124783482149131
# epoch 13820, gradient norm: 0.0005115126568580998
# epoch 13840, gradient norm: 0.0005105495612847369
# epoch 13860, gradient norm: 0.0005095890517661121
# epoch 13880, gradient norm: 0.0005086311186227816
# epoch 13900, gradient norm: 0.0005076757522242375
# epoch 13920, gradient norm: 0.0005067229429885797
# epoch 13940, gradient norm: 0.0005057726813821913
# epoch 13960, gradient norm: 0.000504824957919415
# epoch 13980, gradient norm: 0.0005038797631622353
# epoch 14000, gradient norm: 0.0005029370877199592
# epoch 14020, gradient norm: 0.0005019969222489035
# epoch 14040, gradient norm: 0.0005010592574520817
# epoch 14060, gradient norm: 0.000500124084078897
# epoch 14080, gradient norm: 0.0004991913929248333
# epoch 14100, gradient norm: 0.0004982611748311536
# epoch 14120, gradient norm: 0.0004973334206845982
# epoch 14140, gradient norm: 0.0004964081214170853
# epoch 14160, gradient norm: 0.0004954852680054149
# epoch 14180, gradient norm: 0.0004945648514709756
# epoch 14200, gradient norm: 0.0004936468628794525
# epoch 14220, gradient norm: 0.0004927312933405405
# epoch 14240, gradient norm: 0.000491818134007654
# epoch 14260, gradient norm: 0.0004909073760776473
# epoch 14280, gradient norm: 0.0004899990107905287
# epoch 14300, gradient norm: 0.0004890930294291848
# epoch 14320, gradient norm: 0.00048818942331910024
# epoch 14340, gradient norm: 0.0004872881838280856
# epoch 14360, gradient norm: 0.0004863893023660031
# epoch 14380, gradient norm: 0.00048549277038449797
# epoch 14400, gradient norm: 0.00048459857937672746
# epoch 14420, gradient norm: 0.0004837067208770994
# epoch 14440, gradient norm: 0.00048281718646100427
# epoch 14460, gradient norm: 0.0004819299677445559
# epoch 14480, gradient norm: 0.00048104505638433225
# epoch 14500, gradient norm: 0.0004801624440771169
# epoch 14520, gradient norm: 0.00047928212255964465
# epoch 14540, gradient norm: 0.00047840408360834825
# epoch 14560, gradient norm: 0.00047752831903910775
# epoch 14580, gradient norm: 0.00047665482070700075
# epoch 14600, gradient norm: 0.00047578358050605454
# epoch 14620, gradient norm: 0.00047491459036900455
# epoch 14640, gradient norm: 0.00047404784226704643
# epoch 14660, gradient norm: 0.0004731833282095991
# epoch 14680, gradient norm: 0.0004723210402440634
# epoch 14700, gradient norm: 0.00047146097045558415
# epoch 14720, gradient norm: 0.0004706031109668168
# epoch 14740, gradient norm: 0.00046974745393769306
# epoch 14760, gradient norm: 0.00046889399156518837
# epoch 14780, gradient norm: 0.0004680427160830933
# epoch 14800, gradient norm: 0.0004671936197617852
# epoch 14820, gradient norm: 0.0004663466949080011
# epoch 14840, gradient norm: 0.0004655019338646142
# epoch 14860, gradient norm: 0.0004646593290104115
# epoch 14880, gradient norm: 0.00046381887275987165
# epoch 14900, gradient norm: 0.00046298055756294746
# epoch 14920, gradient norm: 0.0004621443759048465
# epoch 14940, gradient norm: 0.00046131032030581723
# epoch 14960, gradient norm: 0.0004604783833209339
# epoch 14980, gradient norm: 0.0004596485575398838
# epoch 15000, gradient norm: 0.0004588208355867571
# epoch 15020, gradient norm: 0.00045799521011983857
# epoch 15040, gradient norm: 0.00045717167383139783
# epoch 15060, gradient norm: 0.0004563502194474862
# epoch 15080, gradient norm: 0.0004555308397277296
# epoch 15100, gradient norm: 0.00045471352746512874
# epoch 15120, gradient norm: 0.00045389827548585515
# epoch 15140, gradient norm: 0.000453085076649054
# epoch 15160, gradient norm: 0.00045227392384664415
# epoch 15180, gradient norm: 0.0004514648100031229
# epoch 15200, gradient norm: 0.00045065772807537015
# epoch 15220, gradient norm: 0.0004498526710524547
# epoch 15240, gradient norm: 0.0004490496319554437
# epoch 15260, gradient norm: 0.0004482486038372094
# epoch 15280, gradient norm: 0.00044744957978224277
# epoch 15300, gradient norm: 0.00044665255290646363
# epoch 15320, gradient norm: 0.00044585751635703533
# epoch 15340, gradient norm: 0.0004450644633121798
# epoch 15360, gradient norm: 0.00044427338698099317
# epoch 15380, gradient norm: 0.0004434842806032649
# epoch 15400, gradient norm: 0.0004426971374492964
# epoch 15420, gradient norm: 0.00044191195081972164
# epoch 15440, gradient norm: 0.0004411287140453287
# epoch 15460, gradient norm: 0.000440347420486884
# epoch 15480, gradient norm: 0.0004395680635349552
# epoch 15500, gradient norm: 0.00043879063660973936
# epoch 15520, gradient norm: 0.00043801513316088844
# epoch 15540, gradient norm: 0.0004372415466673379
# epoch 15560, gradient norm: 0.00043646987063713756
# epoch 15580, gradient norm: 0.0004357000986072817
# epoch 15600, gradient norm: 0.00043493222414354077
# epoch 15620, gradient norm: 0.00043416624084029637
# epoch 15640, gradient norm: 0.00043340214232037494
# epoch 15660, gradient norm: 0.0004326399222348833
# epoch 15680, gradient norm: 0.00043187957426304795
# epoch 15700, gradient norm: 0.00043112109211205005
# epoch 15720, gradient norm: 0.0004303644695168682
# epoch 15740, gradient norm: 0.0004296097002401172
# epoch 15760, gradient norm: 0.0004288567780718901
# epoch 15780, gradient norm: 0.00042810569682960223
# epoch 15800, gradient norm: 0.00042735645035783386
# epoch 15820, gradient norm: 0.00042660903252817676
# epoch 15840, gradient norm: 0.00042586343723908046
# epoch 15860, gradient norm: 0.00042511965841569827
# epoch 15880, gradient norm: 0.0004243776900097383
# epoch 15900, gradient norm: 0.0004236375259993108
# epoch 15920, gradient norm: 0.00042289916038878083
# epoch 15940, gradient norm: 0.00042216258720861936
# epoch 15960, gradient norm: 0.0004214278005152559
# epoch 15980, gradient norm: 0.0004206947943909326
# epoch 16000, gradient norm: 0.00041996356294356
# epoch 16020, gradient norm: 0.0004192341003065722
# epoch 16040, gradient norm: 0.000418506400638784
# epoch 16060, gradient norm: 0.00041778045812425064
# epoch 16080, gradient norm: 0.000417056266972124
# epoch 16100, gradient norm: 0.00041633382141651495
# epoch 16120, gradient norm: 0.0004156131157163547
# epoch 16140, gradient norm: 0.0004148941441552542
# epoch 16160, gradient norm: 0.0004141769010413704
# epoch 16180, gradient norm: 0.0004134613807072687
# epoch 16200, gradient norm: 0.00041274757750978764
# epoch 16220, gradient norm: 0.00041203548582990603
# epoch 16240, gradient norm: 0.0004113251000726089
# epoch 16260, gradient norm: 0.0004106164146667556
# epoch 16280, gradient norm: 0.00040990942406494854
# epoch 16300, gradient norm: 0.00040920412274340266
# epoch 16320, gradient norm: 0.00040850050520181594
# epoch 16340, gradient norm: 0.00040779856596324254
# epoch 16360, gradient norm: 0.00040709829957396166
# epoch 16380, gradient norm: 0.0004063997006033544
# epoch 16400, gradient norm: 0.0004057027636437757
# epoch 16420, gradient norm: 0.00040500748331043007
# epoch 16440, gradient norm: 0.0004043138542412477
# epoch 16460, gradient norm: 0.0004036218710967604
# epoch 16480, gradient norm: 0.00040293152855998005
# epoch 16500, gradient norm: 0.0004022428213362763
# epoch 16520, gradient norm: 0.0004015557441532566
# epoch 16540, gradient norm: 0.00040087029176064505
# epoch 16560, gradient norm: 0.0004001864589301649
# epoch 16580, gradient norm: 0.00039950424045541845
# epoch 16600, gradient norm: 0.0003988236311517719
# epoch 16620, gradient norm: 0.00039814462585623605
# epoch 16640, gradient norm: 0.0003974672194273522
# epoch 16660, gradient norm: 0.00039679140674507655
# epoch 16680, gradient norm: 0.00039611718271066596
# epoch 16700, gradient norm: 0.0003954445422465642
# epoch 16720, gradient norm: 0.00039477348029628924
# epoch 16740, gradient norm: 0.00039410399182432176
# epoch 16760, gradient norm: 0.0003934360718159926
# epoch 16780, gradient norm: 0.0003927697152773742
# epoch 16800, gradient norm: 0.0003921049172351688
# epoch 16820, gradient norm: 0.0003914416727366006
# epoch 16840, gradient norm: 0.0003907799768493078
# epoch 16860, gradient norm: 0.0003901198246612337
# epoch 16880, gradient norm: 0.00038946121128052093
# epoch 16900, gradient norm: 0.0003888041318354053
# epoch 16920, gradient norm: 0.00038814858147410904
# epoch 16940, gradient norm: 0.0003874945553647388
# epoch 16960, gradient norm: 0.00038684204869517797
# epoch 16980, gradient norm: 0.00038619105667298697
# epoch 17000, gradient norm: 0.0003855415745252979
# epoch 17020, gradient norm: 0.00038489359749871395
# epoch 17040, gradient norm: 0.0003842471208592074
# epoch 17060, gradient norm: 0.00038360213989202
# epoch 17080, gradient norm: 0.00038295864990156104
# epoch 17100, gradient norm: 0.00038231664621131054
# epoch 17120, gradient norm: 0.0003816761241637187
# epoch 17140, gradient norm: 0.0003810370791201086
# epoch 17160, gradient norm: 0.0003803995064605789
# epoch 17180, gradient norm: 0.00037976340158390705
# epoch 17200, gradient norm: 0.00037912875990745213
# epoch 17220, gradient norm: 0.00037849557686706173
# epoch 17240, gradient norm: 0.00037786384791697446
# epoch 17260, gradient norm: 0.00037723356852972735
# epoch 17280, gradient norm: 0.0003766047341960624
# epoch 17300, gradient norm: 0.00037597734042483117
# epoch 17320, gradient norm: 0.0003753513827429064
# epoch 17340, gradient norm: 0.0003747268566950859
# epoch 17360, gradient norm: 0.00037410375784400487
# epoch 17380, gradient norm: 0.0003734820817700421
# epoch 17400, gradient norm: 0.0003728618240712328
# epoch 17420, gradient norm: 0.0003722429803631775
# epoch 17440, gradient norm: 0.00037162554627895284
# epoch 17460, gradient norm: 0.0003710095174690244
# epoch 17480, gradient norm: 0.0003703948896011577
# epoch 17500, gradient norm: 0.0003697816583603326
# epoch 17520, gradient norm: 0.0003691698194486546
# epoch 17540, gradient norm: 0.00036855936858527067
# epoch 17560, gradient norm: 0.0003679503015062825
# epoch 17580, gradient norm: 0.00036734261396466084
# epoch 17600, gradient norm: 0.00036673630173016304
# epoch 17620, gradient norm: 0.0003661313605892477
# epoch 17640, gradient norm: 0.0003655277863449918
# epoch 17660, gradient norm: 0.00036492557481700687
# epoch 17680, gradient norm: 0.0003643247218413578
# epoch 17700, gradient norm: 0.00036372522327048046
# epoch 17720, gradient norm: 0.0003631270749730998
# epoch 17740, gradient norm: 0.00036253027283415063
# epoch 17760, gradient norm: 0.00036193481275469564
# epoch 17780, gradient norm: 0.00036134069065184624
# epoch 17800, gradient norm: 0.00036074790245868327
# epoch 17820, gradient norm: 0.00036015644412417785
# epoch 17840, gradient norm: 0.00035956631161311413
# epoch 17860, gradient norm: 0.0003589775009060099
# epoch 17880, gradient norm: 0.0003583900079990396
# epoch 17900, gradient norm: 0.00035780382890395894
# epoch 17920, gradient norm: 0.00035721895964802627
# epoch 17940, gradient norm: 0.0003566353962739283
# epoch 17960, gradient norm: 0.00035605313483970364
# epoch 17980, gradient norm: 0.0003554721714186683
# epoch 18000, gradient norm: 0.0003548925020993414
# epoch 18020, gradient norm: 0.00035431412298537004
# epoch 18040, gradient norm: 0.0003537370301954571
# epoch 18060, gradient norm: 0.0003531612198632867
# epoch 18080, gradient norm: 0.00035258668813745224
# epoch 18100, gradient norm: 0.0003520134311813844
# epoch 18120, gradient norm: 0.00035144144517327777
# epoch 18140, gradient norm: 0.000350870726306022
# epoch 18160, gradient norm: 0.00035030127078712793
# epoch 18180, gradient norm: 0.0003497330748386596
# epoch 18200, gradient norm: 0.0003491661346971625
# epoch 18220, gradient norm: 0.0003486004466135942
# epoch 18240, gradient norm: 0.0003480360068532555
# epoch 18260, gradient norm: 0.00034747281169572174
# epoch 18280, gradient norm: 0.00034691085743477306
# epoch 18300, gradient norm: 0.00034635014037832847
# epoch 18320, gradient norm: 0.00034579065684837637
# epoch 18340, gradient norm: 0.00034523240318090815
# epoch 18360, gradient norm: 0.0003446753757258512
# epoch 18380, gradient norm: 0.00034411957084700263
# epoch 18400, gradient norm: 0.000343564984921964
# epoch 18420, gradient norm: 0.0003430116143420736
# epoch 18440, gradient norm: 0.00034245945551234365
# epoch 18460, gradient norm: 0.0003419085048513942
# epoch 18480, gradient norm: 0.00034135875879138876
# epoch 18500, gradient norm: 0.0003408102137779706
# epoch 18520, gradient norm: 0.0003402628662701985
# epoch 18540, gradient norm: 0.0003397167127404841
# epoch 18560, gradient norm: 0.00033917174967452855
# epoch 18580, gradient norm: 0.0003386279735712603
# epoch 18600, gradient norm: 0.00033808538094277273
# epoch 18620, gradient norm: 0.0003375439683142618
# epoch 18640, gradient norm: 0.00033700373222396516
# epoch 18660, gradient norm: 0.0003364646692231021
# epoch 18680, gradient norm: 0.0003359267758758108
# epoch 18700, gradient norm: 0.0003353900487590884
# epoch 18720, gradient norm: 0.00033485448446273224
# epoch 18740, gradient norm: 0.00033432007958927965
# epoch 18760, gradient norm: 0.0003337868307539475
# epoch 18780, gradient norm: 0.0003332547345845746
# epoch 18800, gradient norm: 0.0003327237877215622
# epoch 18820, gradient norm: 0.00033219398681781664
# epoch 18840, gradient norm: 0.0003316653285386905
# epoch 18860, gradient norm: 0.0003311378095619249
# epoch 18880, gradient norm: 0.00033061142657759266
# epoch 18900, gradient norm: 0.00033008617628804216
# epoch 18920, gradient norm: 0.00032956205540783895
# epoch 18940, gradient norm: 0.0003290390606637104
# epoch 18960, gradient norm: 0.0003285171887944897
# epoch 18980, gradient norm: 0.0003279964365510607
# epoch 19000, gradient norm: 0.0003274768006963013
# epoch 19020, gradient norm: 0.0003269582780050295
# epoch 19040, gradient norm: 0.0003264408652639483
# epoch 19060, gradient norm: 0.00032592455927159134
# epoch 19080, gradient norm: 0.0003254093568382692
# epoch 19100, gradient norm: 0.00032489525478601456
# epoch 19120, gradient norm: 0.0003243822499485301
# epoch 19140, gradient norm: 0.00032387033917113457
# epoch 19160, gradient norm: 0.00032335951931070957
# epoch 19180, gradient norm: 0.00032284978723564803
# epoch 19200, gradient norm: 0.0003223411398258016
# epoch 19220, gradient norm: 0.00032183357397242763
# epoch 19240, gradient norm: 0.00032132708657813924
# epoch 19260, gradient norm: 0.0003208216745568526
# epoch 19280, gradient norm: 0.0003203173348337364
# epoch 19300, gradient norm: 0.00031981406434516095
# epoch 19320, gradient norm: 0.0003193118600386476
# epoch 19340, gradient norm: 0.00031881071887281814
# epoch 19360, gradient norm: 0.00031831063781734677
# epoch 19380, gradient norm: 0.0003178116138529072
# epoch 19400, gradient norm: 0.000317313643971126
# epoch 19420, gradient norm: 0.0003168167251745321
# epoch 19440, gradient norm: 0.0003163208544765087
# epoch 19460, gradient norm: 0.00031582602890124393
# epoch 19480, gradient norm: 0.0003153322454836826
# epoch 19500, gradient norm: 0.0003148395012694799
# epoch 19520, gradient norm: 0.00031434779331495076
# epoch 19540, gradient norm: 0.0003138571186870244
# epoch 19560, gradient norm: 0.0003133674744631967
# epoch 19580, gradient norm: 0.0003128788577314826
# epoch 19600, gradient norm: 0.00031239126559037085
# epoch 19620, gradient norm: 0.000311904695148775
# epoch 19640, gradient norm: 0.0003114191435259899
# epoch 19660, gradient norm: 0.00031093460785164414
# epoch 19680, gradient norm: 0.0003104510852656545
# epoch 19700, gradient norm: 0.0003099685729181819
# epoch 19720, gradient norm: 0.0003094870679695836
# epoch 19740, gradient norm: 0.00030900656759037066
# epoch 19760, gradient norm: 0.00030852706896116204
# epoch 19780, gradient norm: 0.0003080485692726404
# epoch 19800, gradient norm: 0.00030757106572550785
# epoch 19820, gradient norm: 0.00030709455553044255
# epoch 19840, gradient norm: 0.0003066190359080534
# epoch 19860, gradient norm: 0.00030614450408883844
# epoch 19880, gradient norm: 0.0003056709573131401
# epoch 19900, gradient norm: 0.0003051983928311032
# epoch 19920, gradient norm: 0.0003047268079026317
# epoch 19940, gradient norm: 0.0003042561997973458
# epoch 19960, gradient norm: 0.00030378656579454035
# epoch 19980, gradient norm: 0.0003033179031831417
# epoch 20000, gradient norm: 0.0003028502092616674
